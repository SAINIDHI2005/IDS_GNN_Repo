# %% [markdown]
# <a href="https://colab.research.google.com/github/SAINIDHI2005/IDS_GNN_Repo/blob/main/GAT/HostFlowTemporal_GAT_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch-geometric -q

# %%
import os

import pandas as pd
import numpy as np

import torch

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from torch_geometric.data import Data

# %%
DATASET_DIR = "/Users/balji/OneDrive/GNN_IDS/Balanced_6Class_400K"

files = {
    "BENIGN.csv":0,
    "DDoS.csv":1,
    "DoS.csv":1,
    "Mirai.csv":1,
    "Recon.csv":1,
    "Spoofing.csv":1
}

dfs = []

for file,label in files.items():

    path = os.path.join(DATASET_DIR,file)

    df = pd.read_csv(path)

    attack_name = file.replace(".csv","")

    df["attack_type"] = attack_name

    df["label"] = label

    dfs.append(df)

data = pd.concat(
    dfs,
    ignore_index=True
)

print(data.shape)

print(data["attack_type"].value_counts())
# Out:
# (400000, 88)
# attack_type
# BENIGN      200000
# DDoS         40000
# DoS          40000
# Mirai        40000
# Recon        40000
# Spoofing     40000
# Name: count, dtype: int64

# %%
data = data.sort_values(
    "bidirectional_first_seen_ms"
).reset_index(drop=True)

data["flow_id"] = np.arange(len(data))

print(data.shape)
# Out:
# (400000, 89)

# %%
attack_type_backup = data["attack_type"].copy()

# %%
DROP_COLS = [

    "id",
    "expiration_id",

    "src_ip",
    "dst_ip",

    "src_mac",
    "dst_mac",

    "src_oui",
    "dst_oui",

    "requested_server_name",

    "client_fingerprint",
    "server_fingerprint",

    "user_agent",
    "content_type",

    "application_name",
    "application_category_name",

    "flow_id",
    "label",
    "attack_type",

    "bidirectional_first_seen_ms",
    "bidirectional_last_seen_ms",

    "src2dst_first_seen_ms",
    "src2dst_last_seen_ms",

    "dst2src_first_seen_ms",
    "dst2src_last_seen_ms",

    "application_confidence",
    "application_is_guessed",

    "vlan_id",
    "tunnel_id",

    "bidirectional_urg_packets",
    "src2dst_urg_packets",
    "dst2src_urg_packets",

    "dst2src_cwr_packets",
    "dst2src_ece_packets",

    "src_port",

    "bidirectional_duration_ms",
    "bidirectional_packets",

    "src2dst_packets",
    "dst2src_packets",

    "dst2src_min_ps",
    "dst2src_mean_ps",

    "bidirectional_min_piat_ms",
    "bidirectional_stddev_piat_ms",

    "dst2src_min_piat_ms",
    "dst2src_mean_piat_ms",
    "dst2src_max_piat_ms",

    "bidirectional_ece_packets",
    "bidirectional_psh_packets",
    "bidirectional_fin_packets",

    "src2dst_syn_packets",
    "src2dst_cwr_packets",
    "src2dst_ack_packets",
    "src2dst_rst_packets",
    "src2dst_fin_packets",

    "src2dst_mean_piat_ms",
    "src2dst_stddev_ps",

    "dst2src_ack_packets",
    "dst2src_psh_packets",
    "dst2src_rst_packets",
    "dst2src_fin_packets",

]

feature_cols = [

    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:",len(feature_cols))
# Out:
# Features: 30

# %%
feature_cols = [
    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:", len(feature_cols))

print("\nRetained Features:\n")
for i, f in enumerate(feature_cols, start=1):
    print(f"{i:2d}. {f}")
# Out:
# Features: 30
#
# Retained Features:
#
#  1. dst_port
#  2. protocol
#  3. ip_version
#  4. bidirectional_bytes
#  5. src2dst_duration_ms
#  6. src2dst_bytes
#  7. dst2src_duration_ms
#  8. dst2src_bytes
#  9. bidirectional_min_ps
# 10. bidirectional_mean_ps
# 11. bidirectional_stddev_ps
# 12. bidirectional_max_ps
# 13. src2dst_min_ps
# 14. src2dst_mean_ps
# 15. src2dst_max_ps
# 16. dst2src_stddev_ps
# 17. dst2src_max_ps
# 18. bidirectional_mean_piat_ms
# 19. bidirectional_max_piat_ms
# 20. src2dst_min_piat_ms
# 21. src2dst_stddev_piat_ms
# 22. src2dst_max_piat_ms
# 23. dst2src_stddev_piat_ms
# 24. bidirectional_syn_packets
# 25. bidirectional_cwr_packets
# 26. bidirectional_ack_packets
# 27. bidirectional_rst_packets
# 28. src2dst_ece_packets
# 29. src2dst_psh_packets
# 30. dst2src_syn_packets

# %%
top30 = {
    "bidirectional_mean_ps",
    "dst2src_syn_packets",
    "src2dst_min_ps",
    "ip_version",
    "src2dst_max_piat_ms",
    "dst2src_stddev_piat_ms",
    "bidirectional_max_piat_ms",
    "bidirectional_rst_packets",
    "src2dst_max_ps",
    "src2dst_duration_ms",
    "src2dst_bytes",
    "src2dst_ece_packets",
    "bidirectional_max_ps",
    "dst2src_bytes",
    "bidirectional_bytes",
    "dst2src_max_ps",
    "bidirectional_min_ps",
    "bidirectional_syn_packets",
    "dst2src_stddev_ps",
    "bidirectional_ack_packets",
    "protocol",
    "dst_port",
    "bidirectional_mean_piat_ms",
    "dst2src_duration_ms",
    "src2dst_mean_ps",
    "src2dst_min_piat_ms",
    "bidirectional_stddev_ps",
    "src2dst_stddev_piat_ms",
    "bidirectional_cwr_packets",
    "src2dst_psh_packets"
}

retained = set(feature_cols)

print("Missing from retained:")
print(sorted(top30 - retained))

print("\nExtra retained features:")
print(sorted(retained - top30))
# Out:
# Missing from retained:
# []
#
# Extra retained features:
# []

# %%
for col in feature_cols:

    data[col] = pd.to_numeric(
        data[col],
        errors="coerce"
    )

data[feature_cols] = (
    data[feature_cols]
    .fillna(0)
)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(
    data[feature_cols]
)

print(X.shape)
# Out:
# (400000, 30)

# %%
all_hosts = pd.concat(
    [
        data["src_ip"],
        data["dst_ip"]
    ]
).unique()

host_to_id = {

    host : idx + len(data)

    for idx,host
    in enumerate(all_hosts)
}

num_flow_nodes = len(data)

num_host_nodes = len(all_hosts)

print("Flow Nodes:",num_flow_nodes)
print("Host Nodes:",num_host_nodes)
# Out:
# Flow Nodes: 400000
# Host Nodes: 4572

# %%
edges = []

for flow_id,row in data.iterrows():

    src_host = host_to_id[
        row["src_ip"]
    ]

    dst_host = host_to_id[
        row["dst_ip"]
    ]

    edges.append(
        [flow_id,src_host]
    )

    edges.append(
        [src_host,flow_id]
    )

    edges.append(
        [flow_id,dst_host]
    )

    edges.append(
        [dst_host,flow_id]
    )

print("Host-flow edges built")
# Out:
# Host-flow edges built

# %%
src_groups = data.groupby(
    "src_ip"
)["flow_id"].apply(list)

print(
    "Groups:",
    len(src_groups)
)
# Out:
# Groups: 1303

# %%
# ==================================
# TEMPORAL FLOW-FLOW EDGES
# ==================================

src_groups = data.groupby("src_ip")["flow_id"].apply(list)

temporal_edges = 0

for flow_list in src_groups:

    n = len(flow_list)

    if n < 2:
        continue

    for i in range(n):

        f1 = flow_list[i]

        for k in [1, 2, 3]:

            if i + k < n:

                f2 = flow_list[i + k]

                edges.append([f1, f2])
                edges.append([f2, f1])

                temporal_edges += 2

print("Temporal edges added:", temporal_edges)
print("Total edges:", len(edges))
# Out:
# Temporal edges added: 2388190
# Total edges: 3988190

# %%
edge_index = torch.tensor(
    edges,
    dtype=torch.long
).t().contiguous()

print(edge_index.shape)
# Out:
# torch.Size([2, 3988190])

# %%
flow_features = torch.tensor(
    X,
    dtype=torch.float
)

# %%
host_features = torch.zeros(

    (
        num_host_nodes,
        flow_features.shape[1]
    ),

    dtype=torch.float
)

host_counts = np.zeros(
    num_host_nodes
)

for flow_id,row in data.iterrows():

    src_idx = (
        host_to_id[
            row["src_ip"]
        ]
        -
        num_flow_nodes
    )

    dst_idx = (
        host_to_id[
            row["dst_ip"]
        ]
        -
        num_flow_nodes
    )

    host_features[src_idx] += flow_features[flow_id]
    host_features[dst_idx] += flow_features[flow_id]

    host_counts[src_idx] += 1
    host_counts[dst_idx] += 1

for i in range(num_host_nodes):

    if host_counts[i] > 0:

        host_features[i] /= (
            host_counts[i]
        )

# %%
x = torch.cat(
    [
        flow_features,
        host_features
    ],
    dim=0
)

print(x.shape)
# Out:
# torch.Size([404572, 30])

# %%
flow_labels = torch.tensor(
    data["label"].values,
    dtype=torch.long
)

host_labels = torch.full(
    (
        num_host_nodes,
    ),
    -1,
    dtype=torch.long
)

y = torch.cat(
    [
        flow_labels,
        host_labels
    ]
)

print(y.shape)
# Out:
# torch.Size([404572])

# %%
flow_hosts = (
    data["src_ip"].astype(str)
    + "_"
    + data["dst_ip"].astype(str)
)

unique_pairs = flow_hosts.unique()

train_pairs, val_pairs = train_test_split(
    unique_pairs,
    test_size=0.2,
    random_state=42
)

train_idx = data[
    flow_hosts.isin(train_pairs)
].index.values

val_idx = data[
    flow_hosts.isin(val_pairs)
].index.values

print("Train flows:", len(train_idx))
print("Validation flows:", len(val_idx))

print("Train pairs:", len(train_pairs))
print("Validation pairs:", len(val_pairs))
# Out:
# Train flows: 313332
# Validation flows: 86668
# Train pairs: 9756
# Validation pairs: 2439

# %%
total_nodes = (
    num_flow_nodes
    +
    num_host_nodes
)

train_mask = torch.zeros(total_nodes,dtype=torch.bool)

val_mask = torch.zeros(total_nodes,dtype=torch.bool)

train_mask[train_idx] = True
val_mask[val_idx] = True

print("Train mask:", train_mask.sum().item())
print("Validation mask :",val_mask.sum().item())
# Out:
# Train mask: 313332
# Validation mask : 86668
# C:\Users\balji\AppData\Local\Temp\ipykernel_33408\3493698591.py:11: UserWarning: The given NumPy array is not writable, and PyTorch does not support non-writable tensors. This means writing to this tensor will result in undefined behavior. You may want to copy the array to protect its data or make it writable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:219.)
#   train_mask[train_idx] = True

# %%
graph = Data(
    x=x,
    edge_index=edge_index,
    y=y,
    train_mask=train_mask,
    val_mask=val_mask
)
print(graph)

print(
    "Nodes:",
    graph.num_nodes
)

print(
    "Edges:",
    graph.num_edges
)
# Out:
# Data(x=[404572, 30], edge_index=[2, 3988190], y=[404572], train_mask=[404572], val_mask=[404572])
# Nodes: 404572
# Edges: 3988190

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv

class GATModel(torch.nn.Module):
    def __init__(
        self,
        in_channels,
        hidden_channels,
        num_classes,
        heads=4
    ):
        super().__init__()

        # Layer 1
        self.conv1 = GATv2Conv(
            in_channels,
            hidden_channels // heads,
            heads=heads
        )

        # Layer 2
        self.conv2 = GATv2Conv(
            hidden_channels,
            hidden_channels // heads,
            heads=heads
        )

        # Layer 3: Output matches hidden_channels // 2 (128)
        self.conv3 = GATv2Conv(
            hidden_channels,
            (hidden_channels // 2) // heads,
            heads=heads
        )

        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.bn3 = torch.nn.BatchNorm1d(hidden_channels // 2)

        self.classifier = torch.nn.Linear(
            hidden_channels // 2,
            num_classes
        )

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.dropout(x, p=0.4, training=self.training)

        x = self.conv2(x, edge_index)
        x = self.bn2(x)
        x = F.relu(x)
        x = F.dropout(x, p=0.4, training=self.training)

        x = self.conv3(x, edge_index)
        x = self.bn3(x)
        x = F.relu(x)

        x = self.classifier(x)

        return x

# %%
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print(device)
# Out:
# cuda

# %%
model = GATModel(
    in_channels=graph.num_node_features,
    hidden_channels=256,
    num_classes=2
)

model = model.to(device)

graph = graph.to(device)

print(model)
# Out:
# GATModel(
#   (conv1): GATv2Conv(30, 64, heads=4)
#   (conv2): GATv2Conv(256, 64, heads=4)
#   (conv3): GATv2Conv(256, 32, heads=4)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
from torch_geometric.loader import NeighborLoader

train_loader = NeighborLoader(
    graph,
    input_nodes=graph.train_mask,
    num_neighbors=[15, 10],
    batch_size=2048,
    shuffle=True
)

val_loader = NeighborLoader(
    graph,
    input_nodes=graph.val_mask,
    num_neighbors=[15, 10],
    batch_size=2048,
    shuffle=False
)

print("Train batches :", len(train_loader))
print("Validation batches :", len(val_loader))
# Out:
# Train batches : 153
# Validation batches : 43

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.002,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=20,
    gamma=0.5
)

# %%
weights = torch.tensor(
    [1.0, 1.5],
    dtype=torch.float
).to(device)

criterion = torch.nn.CrossEntropyLoss(
    weight=weights
)

# %%
def train():

    model.train()

    total_loss = 0

    for batch in train_loader:

        batch = batch.to(device)

        optimizer.zero_grad()

        out = model(
            batch.x,
            batch.edge_index
        )

        loss = criterion(
            out[:batch.batch_size],
            batch.y[:batch.batch_size]
        )

        loss.backward()

        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(train_loader)

# %%
@torch.no_grad()

def evaluate(loader):

    model.eval()

    correct = 0
    total = 0

    for batch in loader:

        batch = batch.to(device)

        out = model(
            batch.x,
            batch.edge_index
        )

        pred = out[:batch.batch_size].argmax(dim=1)

        correct += (
            pred ==
            batch.y[:batch.batch_size]
        ).sum().item()

        total += batch.batch_size

    return correct / total

# %%
import os
import time
import joblib
import torch

best_val_acc = 0.0
best_epoch = 0

SAVE_DIR = r"/Users/balji/OneDrive/GNN_IDS/HostFlow_Saved_Model"
os.makedirs(SAVE_DIR, exist_ok=True)

start_time = time.time()

for epoch in range(1, 151):

   loss = train()

   train_acc = evaluate(train_loader)

   val_acc = evaluate(val_loader)

   # Save best model based on validation accuracy
   if val_acc > best_val_acc:

        best_val_acc = val_acc
        best_epoch = epoch

        torch.save(
            model.state_dict(),
            os.path.join(
                SAVE_DIR,
                "HostFlowTemporal_GATmodel.pth"
            )
        )

        joblib.dump(
            scaler,
            os.path.join(
                SAVE_DIR,
                "HostFlowTemporal _SCALERmodel.pkl"
            )
        )
   scheduler.step()

   print(
        f"Epoch {epoch:03d}"
        f" | Loss {loss:.4f}"
        f" | Train {train_acc:.4f}"
        f" | Validation {val_acc:.4f}"
   )

end_time = time.time()

training_time = end_time - start_time

print("\n" + "=" * 60)
print(f"Training Time          : {training_time:.2f} seconds")
print(f"Best Epoch             : {best_epoch}")
print(f"Best Validation Acc.   : {best_val_acc:.4f}")
print(f"Model Saved At         : {os.path.join(SAVE_DIR,'HostFlowTemporal_GATmodel.pth')}")
print(f"Scaler Saved At        : {os.path.join(SAVE_DIR,'HostFlowTemporal _SCALERmodel.pkl')}")
print("=" * 60)
print("Training Complete.")
# Out:
# Epoch 001 | Loss 0.2253 | Train 0.9456 | Validation 0.9190
# Epoch 002 | Loss 0.1293 | Train 0.9670 | Validation 0.9204
# Epoch 003 | Loss 0.1026 | Train 0.9701 | Validation 0.9402
# Epoch 004 | Loss 0.0870 | Train 0.9787 | Validation 0.9580
# Epoch 005 | Loss 0.0752 | Train 0.9803 | Validation 0.9594
# Epoch 006 | Loss 0.0745 | Train 0.9816 | Validation 0.9622
# Epoch 007 | Loss 0.0644 | Train 0.9829 | Validation 0.9628
# Epoch 008 | Loss 0.0541 | Train 0.9860 | Validation 0.9736
# Epoch 009 | Loss 0.0510 | Train 0.9868 | Validation 0.9693
# Epoch 010 | Loss 0.0464 | Train 0.9888 | Validation 0.9755
# Epoch 011 | Loss 0.0437 | Train 0.9887 | Validation 0.9713
# Epoch 012 | Loss 0.0398 | Train 0.9897 | Validation 0.9718
# Epoch 013 | Loss 0.0406 | Train 0.9905 | Validation 0.9741
# Epoch 014 | Loss 0.0367 | Train 0.9910 | Validation 0.9750
# Epoch 015 | Loss 0.0340 | Train 0.9908 | Validation 0.9764
# Epoch 016 | Loss 0.0331 | Train 0.9916 | Validation 0.9732
# Epoch 017 | Loss 0.0318 | Train 0.9924 | Validation 0.9800
# Epoch 018 | Loss 0.0324 | Train 0.9918 | Validation 0.9793
# Epoch 019 | Loss 0.0297 | Train 0.9924 | Validation 0.9795
# Epoch 020 | Loss 0.0291 | Train 0.9918 | Validation 0.9805
# Epoch 021 | Loss 0.0245 | Train 0.9938 | Validation 0.9823
# Epoch 022 | Loss 0.0232 | Train 0.9938 | Validation 0.9817
# Epoch 023 | Loss 0.0235 | Train 0.9938 | Validation 0.9825
# Epoch 024 | Loss 0.0248 | Train 0.9932 | Validation 0.9837
# Epoch 025 | Loss 0.0231 | Train 0.9933 | Validation 0.9821
# Epoch 026 | Loss 0.0225 | Train 0.9941 | Validation 0.9827
# Epoch 027 | Loss 0.0232 | Train 0.9942 | Validation 0.9829
# Epoch 028 | Loss 0.0226 | Train 0.9942 | Validation 0.9834
# Epoch 029 | Loss 0.0225 | Train 0.9943 | Validation 0.9827
# Epoch 030 | Loss 0.0215 | Train 0.9943 | Validation 0.9844
# Epoch 031 | Loss 0.0218 | Train 0.9938 | Validation 0.9825
# Epoch 032 | Loss 0.0213 | Train 0.9945 | Validation 0.9838
# Epoch 033 | Loss 0.0215 | Train 0.9946 | Validation 0.9834
# Epoch 034 | Loss 0.0209 | Train 0.9944 | Validation 0.9831
# Epoch 035 | Loss 0.0230 | Train 0.9947 | Validation 0.9834
# Epoch 036 | Loss 0.0206 | Train 0.9942 | Validation 0.9828
# Epoch 037 | Loss 0.0204 | Train 0.9945 | Validation 0.9829
# Epoch 038 | Loss 0.0216 | Train 0.9940 | Validation 0.9850
# Epoch 039 | Loss 0.0209 | Train 0.9943 | Validation 0.9833
# Epoch 040 | Loss 0.0205 | Train 0.9948 | Validation 0.9829
# Epoch 041 | Loss 0.0174 | Train 0.9950 | Validation 0.9844
# Epoch 042 | Loss 0.0179 | Train 0.9950 | Validation 0.9850
# Epoch 043 | Loss 0.0169 | Train 0.9952 | Validation 0.9851
# Epoch 044 | Loss 0.0170 | Train 0.9956 | Validation 0.9857
# Epoch 045 | Loss 0.0173 | Train 0.9954 | Validation 0.9841
# Epoch 046 | Loss 0.0174 | Train 0.9950 | Validation 0.9855
# Epoch 047 | Loss 0.0172 | Train 0.9956 | Validation 0.9852
# Epoch 048 | Loss 0.0167 | Train 0.9952 | Validation 0.9849
# Epoch 049 | Loss 0.0170 | Train 0.9954 | Validation 0.9867
# Epoch 050 | Loss 0.0168 | Train 0.9955 | Validation 0.9866
# Epoch 051 | Loss 0.0169 | Train 0.9954 | Validation 0.9864
# Epoch 052 | Loss 0.0173 | Train 0.9952 | Validation 0.9849
# Epoch 053 | Loss 0.0170 | Train 0.9954 | Validation 0.9857
# Epoch 054 | Loss 0.0170 | Train 0.9952 | Validation 0.9871
# Epoch 055 | Loss 0.0163 | Train 0.9956 | Validation 0.9859
# Epoch 056 | Loss 0.0163 | Train 0.9953 | Validation 0.9847
# Epoch 057 | Loss 0.0165 | Train 0.9957 | Validation 0.9864
# Epoch 058 | Loss 0.0169 | Train 0.9954 | Validation 0.9854
# Epoch 059 | Loss 0.0162 | Train 0.9953 | Validation 0.9862
# Epoch 060 | Loss 0.0165 | Train 0.9955 | Validation 0.9864
# Epoch 061 | Loss 0.0147 | Train 0.9959 | Validation 0.9864
# Epoch 062 | Loss 0.0148 | Train 0.9958 | Validation 0.9848
# Epoch 063 | Loss 0.0147 | Train 0.9960 | Validation 0.9868
# Epoch 064 | Loss 0.0141 | Train 0.9959 | Validation 0.9867
# Epoch 065 | Loss 0.0146 | Train 0.9959 | Validation 0.9871
# Epoch 066 | Loss 0.0143 | Train 0.9960 | Validation 0.9880
# Epoch 067 | Loss 0.0140 | Train 0.9960 | Validation 0.9861
# Epoch 068 | Loss 0.0147 | Train 0.9959 | Validation 0.9880
# Epoch 069 | Loss 0.0145 | Train 0.9960 | Validation 0.9874
# Epoch 070 | Loss 0.0141 | Train 0.9960 | Validation 0.9876
# Epoch 071 | Loss 0.0143 | Train 0.9962 | Validation 0.9872
# Epoch 072 | Loss 0.0138 | Train 0.9961 | Validation 0.9873
# Epoch 073 | Loss 0.0140 | Train 0.9963 | Validation 0.9869
# Epoch 074 | Loss 0.0142 | Train 0.9960 | Validation 0.9863
# Epoch 075 | Loss 0.0143 | Train 0.9963 | Validation 0.9878
# Epoch 076 | Loss 0.0139 | Train 0.9961 | Validation 0.9860
# Epoch 077 | Loss 0.0138 | Train 0.9961 | Validation 0.9886
# Epoch 078 | Loss 0.0136 | Train 0.9960 | Validation 0.9879
# Epoch 079 | Loss 0.0139 | Train 0.9960 | Validation 0.9872
# Epoch 080 | Loss 0.0140 | Train 0.9961 | Validation 0.9877
# Epoch 081 | Loss 0.0128 | Train 0.9963 | Validation 0.9870
# Epoch 082 | Loss 0.0127 | Train 0.9963 | Validation 0.9872
# Epoch 083 | Loss 0.0130 | Train 0.9963 | Validation 0.9865
# Epoch 084 | Loss 0.0129 | Train 0.9963 | Validation 0.9878
# Epoch 085 | Loss 0.0128 | Train 0.9963 | Validation 0.9875
# Epoch 086 | Loss 0.0128 | Train 0.9963 | Validation 0.9871
# Epoch 087 | Loss 0.0125 | Train 0.9959 | Validation 0.9864
# Epoch 088 | Loss 0.0125 | Train 0.9961 | Validation 0.9873
# Epoch 089 | Loss 0.0126 | Train 0.9962 | Validation 0.9866
# Epoch 090 | Loss 0.0124 | Train 0.9964 | Validation 0.9870
# Epoch 091 | Loss 0.0129 | Train 0.9965 | Validation 0.9890
# Epoch 092 | Loss 0.0127 | Train 0.9965 | Validation 0.9880
# Epoch 093 | Loss 0.0124 | Train 0.9963 | Validation 0.9878
# Epoch 094 | Loss 0.0126 | Train 0.9965 | Validation 0.9874
# Epoch 095 | Loss 0.0127 | Train 0.9966 | Validation 0.9878
# Epoch 096 | Loss 0.0125 | Train 0.9965 | Validation 0.9891
# Epoch 097 | Loss 0.0124 | Train 0.9961 | Validation 0.9875
# Epoch 098 | Loss 0.0124 | Train 0.9965 | Validation 0.9885
# Epoch 099 | Loss 0.0126 | Train 0.9966 | Validation 0.9876
# Epoch 100 | Loss 0.0122 | Train 0.9964 | Validation 0.9869
# Epoch 101 | Loss 0.0121 | Train 0.9965 | Validation 0.9880
# Epoch 102 | Loss 0.0120 | Train 0.9964 | Validation 0.9878
# Epoch 103 | Loss 0.0117 | Train 0.9966 | Validation 0.9883
# Epoch 104 | Loss 0.0115 | Train 0.9967 | Validation 0.9880
# Epoch 105 | Loss 0.0119 | Train 0.9966 | Validation 0.9884
# Epoch 106 | Loss 0.0121 | Train 0.9966 | Validation 0.9869
# Epoch 107 | Loss 0.0114 | Train 0.9966 | Validation 0.9886
# Epoch 108 | Loss 0.0119 | Train 0.9967 | Validation 0.9885
# Epoch 109 | Loss 0.0117 | Train 0.9965 | Validation 0.9869
# Epoch 110 | Loss 0.0115 | Train 0.9966 | Validation 0.9876
# Epoch 111 | Loss 0.0118 | Train 0.9967 | Validation 0.9876
# Epoch 112 | Loss 0.0119 | Train 0.9967 | Validation 0.9887
# Epoch 113 | Loss 0.0119 | Train 0.9966 | Validation 0.9882
# Epoch 114 | Loss 0.0115 | Train 0.9967 | Validation 0.9886
# Epoch 115 | Loss 0.0118 | Train 0.9968 | Validation 0.9885
# Epoch 116 | Loss 0.0113 | Train 0.9966 | Validation 0.9883
# Epoch 117 | Loss 0.0114 | Train 0.9967 | Validation 0.9876
# Epoch 118 | Loss 0.0115 | Train 0.9966 | Validation 0.9875
# Epoch 119 | Loss 0.0115 | Train 0.9968 | Validation 0.9882
# Epoch 120 | Loss 0.0118 | Train 0.9968 | Validation 0.9880
# Epoch 121 | Loss 0.0114 | Train 0.9969 | Validation 0.9885
# Epoch 122 | Loss 0.0110 | Train 0.9966 | Validation 0.9892
# Epoch 123 | Loss 0.0112 | Train 0.9969 | Validation 0.9888
# Epoch 124 | Loss 0.0111 | Train 0.9968 | Validation 0.9880
# Epoch 125 | Loss 0.0111 | Train 0.9968 | Validation 0.9873
# Epoch 126 | Loss 0.0113 | Train 0.9968 | Validation 0.9879
# Epoch 127 | Loss 0.0112 | Train 0.9968 | Validation 0.9877
# Epoch 128 | Loss 0.0113 | Train 0.9967 | Validation 0.9887
# Epoch 129 | Loss 0.0114 | Train 0.9967 | Validation 0.9881
# Epoch 130 | Loss 0.0110 | Train 0.9967 | Validation 0.9885
# Epoch 131 | Loss 0.0113 | Train 0.9968 | Validation 0.9893
# Epoch 132 | Loss 0.0113 | Train 0.9968 | Validation 0.9881
# Epoch 133 | Loss 0.0112 | Train 0.9968 | Validation 0.9877
# Epoch 134 | Loss 0.0113 | Train 0.9967 | Validation 0.9869
# Epoch 135 | Loss 0.0113 | Train 0.9968 | Validation 0.9894
# Epoch 136 | Loss 0.0115 | Train 0.9967 | Validation 0.9880
# Epoch 137 | Loss 0.0110 | Train 0.9968 | Validation 0.9883
# Epoch 138 | Loss 0.0111 | Train 0.9968 | Validation 0.9870
# Epoch 139 | Loss 0.0110 | Train 0.9969 | Validation 0.9871
# Epoch 140 | Loss 0.0112 | Train 0.9968 | Validation 0.9886
# Epoch 141 | Loss 0.0110 | Train 0.9968 | Validation 0.9876
# Epoch 142 | Loss 0.0111 | Train 0.9968 | Validation 0.9879
# Epoch 143 | Loss 0.0108 | Train 0.9969 | Validation 0.9882
# Epoch 144 | Loss 0.0110 | Train 0.9968 | Validation 0.9881
# Epoch 145 | Loss 0.0108 | Train 0.9969 | Validation 0.9881
# Epoch 146 | Loss 0.0109 | Train 0.9969 | Validation 0.9877
# Epoch 147 | Loss 0.0110 | Train 0.9968 | Validation 0.9874
# Epoch 148 | Loss 0.0108 | Train 0.9969 | Validation 0.9879
# Epoch 149 | Loss 0.0109 | Train 0.9969 | Validation 0.9880
# Epoch 150 | Loss 0.0110 | Train 0.9969 | Validation 0.9878
#
# ============================================================
# Training Time          : 2219.43 seconds
# Best Epoch             : 135
# Best Validation Acc.   : 0.9894
# Model Saved At         : /Users/balji/OneDrive/GNN_IDS/HostFlow_Saved_Model\HostFlowTemporal_GATmodel.pth
# Scaler Saved At        : /Users/balji/OneDrive/GNN_IDS/HostFlow_Saved_Model\HostFlowTemporal _SCALERmodel.pkl
# ============================================================
# Training Complete.

# %%
import time
import torch

print("=" * 60)

# Training Time
print(f"Training Time: {training_time:.2f} seconds ({150} epochs)\n")

# GPU Memory
if torch.cuda.is_available():

    allocated = torch.cuda.memory_allocated() / (1024 ** 2)
    reserved = torch.cuda.memory_reserved() / (1024 ** 2)
    max_reserved = torch.cuda.max_memory_reserved() / (1024 ** 2)

    print(f"Allocated GPU Memory: {allocated:.2f} MB")
    print(f"Reserved GPU Memory: {reserved:.2f} MB")
    print(f"Max GPU Memory: {max_reserved:.2f} MB\n")

# Model Parameters
total_params = sum(
    p.numel() for p in model.parameters()
)

trainable_params = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print(f"Total Parameters: {total_params}")
print(f"Trainable Parameters: {trainable_params}\n")

# Graph Memory
node_memory = (
    graph.x.element_size()
    * graph.x.nelement()
) / (1024 ** 2)

edge_memory = (
    graph.edge_index.element_size()
    * graph.edge_index.nelement()
) / (1024 ** 2)

graph_memory = node_memory + edge_memory

print(f"Node Feature Memory: {node_memory:.2f} MB")
print(f"Edge Memory: {edge_memory:.2f} MB")
print(f"Total Graph Memory: {graph_memory:.2f} MB")

print("=" * 60)
# Out:
# ============================================================
# Training Time: 2219.43 seconds (150 epochs)
#
# Allocated GPU Memory: 131.57 MB
# Reserved GPU Memory: 3164.00 MB
# Max GPU Memory: 3164.00 MB
#
# Total Parameters: 216066
# Trainable Parameters: 216066
#
# Node Feature Memory: 46.30 MB
# Edge Memory: 60.85 MB
# Total Graph Memory: 107.15 MB
# ============================================================
