# %% [markdown]
# <a href="https://colab.research.google.com/github/SAINIDHI2005/IDS_GNN_Repo/blob/main/GAT/FlowFlow_GAT_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torch-geometric -q

# %%
import os

import pandas as pd
import numpy as np

import torch

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from torch_geometric.data import Data

# %%
DATASET_DIR = "/Users/balji/OneDrive/GNN_IDS/Balanced_6Class_400K"

files = {
    "BENIGN.csv":0,
    "DDoS.csv":1,
    "DoS.csv":1,
    "Mirai.csv":1,
    "Recon.csv":1,
    "Spoofing.csv":1
}

dfs = []

for file,label in files.items():

    path = os.path.join(DATASET_DIR,file)

    df = pd.read_csv(path)

    attack_name = file.replace(".csv","")

    df["attack_type"] = attack_name

    df["label"] = label

    dfs.append(df)

data = pd.concat(
    dfs,
    ignore_index=True
)

print(data.shape)

print(data["attack_type"].value_counts())
# Out:
# (400000, 88)
# attack_type
# BENIGN      200000
# DDoS         40000
# DoS          40000
# Mirai        40000
# Recon        40000
# Spoofing     40000
# Name: count, dtype: int64

# %%
data = data.sort_values(
    "bidirectional_first_seen_ms"
).reset_index(drop=True)

data["flow_id"] = np.arange(len(data))

print(data.shape)
# Out:
# (400000, 89)

# %%
attack_type_backup = data["attack_type"].copy()

# %%
DROP_COLS = [

    "id",
    "expiration_id",

    "src_ip",
    "dst_ip",

    "src_mac",
    "dst_mac",

    "src_oui",
    "dst_oui",

    "requested_server_name",

    "client_fingerprint",
    "server_fingerprint",

    "user_agent",
    "content_type",

    "application_name",
    "application_category_name",

    "flow_id",
    "label",
    "attack_type",

    "bidirectional_first_seen_ms",
    "bidirectional_last_seen_ms",

    "src2dst_first_seen_ms",
    "src2dst_last_seen_ms",

    "dst2src_first_seen_ms",
    "dst2src_last_seen_ms",

    "application_confidence",
    "application_is_guessed",

    "vlan_id",
    "tunnel_id",

    "bidirectional_urg_packets",
    "src2dst_urg_packets",
    "dst2src_urg_packets",

    "dst2src_cwr_packets",
    "dst2src_ece_packets",

    "src_port",

    "bidirectional_duration_ms",
    "bidirectional_packets",

    "src2dst_packets",
    "dst2src_packets",

    "dst2src_min_ps",
    "dst2src_mean_ps",

    "bidirectional_min_piat_ms",
    "bidirectional_stddev_piat_ms",

    "dst2src_min_piat_ms",
    "dst2src_mean_piat_ms",
    "dst2src_max_piat_ms",

    "bidirectional_ece_packets",
    "bidirectional_psh_packets",
    "bidirectional_fin_packets",

    "src2dst_syn_packets",
    "src2dst_cwr_packets",
    "src2dst_ack_packets",
    "src2dst_rst_packets",
    "src2dst_fin_packets",

    "src2dst_mean_piat_ms",
    "src2dst_stddev_ps",

    "dst2src_ack_packets",
    "dst2src_psh_packets",
    "dst2src_rst_packets",
    "dst2src_fin_packets",

]

feature_cols = [

    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:",len(feature_cols))
# Out:
# Features: 30

# %%
feature_cols = [
    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:", len(feature_cols))

print("\nRetained Features:\n")
for i, f in enumerate(feature_cols, start=1):
    print(f"{i:2d}. {f}")
# Out:
# Features: 30
#
# Retained Features:
#
#  1. dst_port
#  2. protocol
#  3. ip_version
#  4. bidirectional_bytes
#  5. src2dst_duration_ms
#  6. src2dst_bytes
#  7. dst2src_duration_ms
#  8. dst2src_bytes
#  9. bidirectional_min_ps
# 10. bidirectional_mean_ps
# 11. bidirectional_stddev_ps
# 12. bidirectional_max_ps
# 13. src2dst_min_ps
# 14. src2dst_mean_ps
# 15. src2dst_max_ps
# 16. dst2src_stddev_ps
# 17. dst2src_max_ps
# 18. bidirectional_mean_piat_ms
# 19. bidirectional_max_piat_ms
# 20. src2dst_min_piat_ms
# 21. src2dst_stddev_piat_ms
# 22. src2dst_max_piat_ms
# 23. dst2src_stddev_piat_ms
# 24. bidirectional_syn_packets
# 25. bidirectional_cwr_packets
# 26. bidirectional_ack_packets
# 27. bidirectional_rst_packets
# 28. src2dst_ece_packets
# 29. src2dst_psh_packets
# 30. dst2src_syn_packets

# %%
top30 = {
    "bidirectional_mean_ps",
    "dst2src_syn_packets",
    "src2dst_min_ps",
    "ip_version",
    "src2dst_max_piat_ms",
    "dst2src_stddev_piat_ms",
    "bidirectional_max_piat_ms",
    "bidirectional_rst_packets",
    "src2dst_max_ps",
    "src2dst_duration_ms",
    "src2dst_bytes",
    "src2dst_ece_packets",
    "bidirectional_max_ps",
    "dst2src_bytes",
    "bidirectional_bytes",
    "dst2src_max_ps",
    "bidirectional_min_ps",
    "bidirectional_syn_packets",
    "dst2src_stddev_ps",
    "bidirectional_ack_packets",
    "protocol",
    "dst_port",
    "bidirectional_mean_piat_ms",
    "dst2src_duration_ms",
    "src2dst_mean_ps",
    "src2dst_min_piat_ms",
    "bidirectional_stddev_ps",
    "src2dst_stddev_piat_ms",
    "bidirectional_cwr_packets",
    "src2dst_psh_packets"
}

retained = set(feature_cols)

print("Missing from retained:")
print(sorted(top30 - retained))

print("\nExtra retained features:")
print(sorted(retained - top30))
# Out:
# Missing from retained:
# []
#
# Extra retained features:
# []

# %%
for col in feature_cols:

    data[col] = pd.to_numeric(
        data[col],
        errors="coerce"
    )

data[feature_cols] = (
    data[feature_cols]
    .fillna(0)
)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(
    data[feature_cols]
)

print(X.shape)
# Out:
# (400000, 30)

# %%
num_flow_nodes = len(data)

print("Flow Nodes:", num_flow_nodes)
# Out:
# Flow Nodes: 400000

# %%
from tqdm import tqdm

print("Building Flow-Flow Graph with Temporal Constraint...")

TIME_WINDOW_MS = 100      # 2-second temporal window

source_nodes = []
target_nodes = []

# Group by communication profile
grouped = data.groupby(
    ["protocol", "dst_ip", "dst_port"]
)

for _, group in tqdm(grouped, desc="Creating Temporal Edges"):

    # Sort flows chronologically
    group = group.sort_values("bidirectional_first_seen_ms")

    # FIX: Use 'flow_id' instead of 'id' to ensure 0-indexed, sequential node IDs
    node_ids = group["flow_id"].values
    timestamps = group["bidirectional_first_seen_ms"].values

    n = len(node_ids)

    # Sliding Window
    left = 0

    for right in range(n):

        while timestamps[right] - timestamps[left] > TIME_WINDOW_MS:
            left += 1

        # Connect current flow with previous flows inside window
        for i in range(left, right):

            source_nodes.append(node_ids[right])
            target_nodes.append(node_ids[i])

            source_nodes.append(node_ids[i])
            target_nodes.append(node_ids[right])

edge_index = torch.tensor(
    [source_nodes, target_nodes],
    dtype=torch.long
)

print("\nEdge construction complete.")
print(edge_index.shape)
# Out:
# Building Flow-Flow Graph with Temporal Constraint...
# Creating Temporal Edges: 100%|██████████| 57299/57299 [00:18<00:00, 3049.98it/s]
# Edge construction complete.
# torch.Size([2, 4519560])

# %%
x = torch.tensor(
    X,
    dtype=torch.float
)

print(x.shape)
# Out:
# torch.Size([400000, 30])

# %%
y = torch.tensor(
    data["label"].values,
    dtype=torch.long
)

print(y.shape)
# Out:
# torch.Size([400000])

# %%
train_idx, val_idx = train_test_split(
    np.arange(num_flow_nodes),
    test_size=0.20,
    stratify=data["label"],
    random_state=42
)

print("Train:", len(train_idx))
print("Validation:", len(val_idx))
# Out:
# Train: 320000
# Validation: 80000

# %%
total_nodes = num_flow_nodes

# %%
train_mask = torch.zeros(total_nodes,dtype=torch.bool)

val_mask = torch.zeros(total_nodes,dtype=torch.bool)

train_mask[train_idx] = True
val_mask[val_idx] = True

print("Train mask:", train_mask.sum().item())
print("Validation mask :",val_mask.sum().item())
# Out:
# Train mask: 320000
# Validation mask : 80000

# %%
graph = Data(
    x=x,
    edge_index=edge_index,
    y=y,
    train_mask=train_mask,
    val_mask=val_mask
)
print(graph)

print(
    "Nodes:",
    graph.num_nodes
)

print(
    "Edges:",
    graph.num_edges
)
# Out:
# Data(x=[400000, 30], edge_index=[2, 4519560], y=[400000], train_mask=[400000], val_mask=[400000])
# Nodes: 400000
# Edges: 4519560

# %%
import torch
import torch.nn.functional as F
from torch_geometric.nn import GATv2Conv

class GATModel(torch.nn.Module):
    def __init__(
        self,
        in_channels,
        hidden_channels,
        num_classes,
        heads=4
    ):
        super().__init__()

        # Layer 1
        self.conv1 = GATv2Conv(
            in_channels,
            hidden_channels // heads,
            heads=heads
        )

        # Layer 2
        self.conv2 = GATv2Conv(
            hidden_channels,
            hidden_channels // heads,
            heads=heads
        )

        # Layer 3: Output matches hidden_channels // 2 (128)
        self.conv3 = GATv2Conv(
            hidden_channels,
            (hidden_channels // 2) // heads,
            heads=heads
        )

        self.bn1 = torch.nn.BatchNorm1d(hidden_channels)
        self.bn2 = torch.nn.BatchNorm1d(hidden_channels)
        self.bn3 = torch.nn.BatchNorm1d(hidden_channels // 2)

        self.classifier = torch.nn.Linear(
            hidden_channels // 2,
            num_classes
        )

    def forward(self, x, edge_index):
        x = self.conv1(x, edge_index)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.dropout(x, p=0.4, training=self.training)

        x = self.conv2(x, edge_index)
        x = self.bn2(x)
        x = F.relu(x)
        x = F.dropout(x, p=0.4, training=self.training)

        x = self.conv3(x, edge_index)
        x = self.bn3(x)
        x = F.relu(x)

        x = self.classifier(x)

        return x

# %%
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print(device)
# Out:
# cuda

# %%
model = GATModel(
    in_channels=graph.num_node_features,
    hidden_channels=256,
    num_classes=2
)

model = model.to(device)

graph = graph.to(device)

print(model)
# Out:
# GATModel(
#   (conv1): GATv2Conv(30, 64, heads=4)
#   (conv2): GATv2Conv(256, 64, heads=4)
#   (conv3): GATv2Conv(256, 32, heads=4)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
from torch_geometric.loader import NeighborLoader

train_loader = NeighborLoader(
    graph,
    input_nodes=graph.train_mask,
    num_neighbors=[15, 10],
    batch_size=2048,
    shuffle=True
)

val_loader = NeighborLoader(
    graph,
    input_nodes=graph.val_mask,
    num_neighbors=[15, 10],
    batch_size=2048,
    shuffle=False
)

print("Train batches :", len(train_loader))
print("Validation batches :", len(val_loader))
# Out:
# Train batches : 157
# Validation batches : 40

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.002,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=20,
    gamma=0.5
)

# %%
weights = torch.tensor(
    [1.0, 1.5],
    dtype=torch.float
).to(device)

criterion = torch.nn.CrossEntropyLoss(
    weight=weights
)

# %%
def train():

    model.train()

    total_loss = 0

    for batch in train_loader:

        batch = batch.to(device)

        optimizer.zero_grad()

        out = model(
            batch.x,
            batch.edge_index
        )

        loss = criterion(
            out[:batch.batch_size],
            batch.y[:batch.batch_size]
        )

        loss.backward()

        optimizer.step()

        total_loss += loss.item()

    return total_loss / len(train_loader)

# %%
@torch.no_grad()

def evaluate(loader):

    model.eval()

    correct = 0
    total = 0

    for batch in loader:

        batch = batch.to(device)

        out = model(
            batch.x,
            batch.edge_index
        )

        pred = out[:batch.batch_size].argmax(dim=1)

        correct += (
            pred ==
            batch.y[:batch.batch_size]
        ).sum().item()

        total += batch.batch_size

    return correct / total

# %%
import os
import time
import joblib
import torch

best_val_acc = 0.0
best_epoch = 0

SAVE_DIR = r"/Users/balji/OneDrive/GNN_IDS/Saved_Model"
os.makedirs(SAVE_DIR, exist_ok=True)

start_time = time.time()

for epoch in range(1, 151):

   loss = train()

   train_acc = evaluate(train_loader)

   val_acc = evaluate(val_loader)

   # Save best model based on validation accuracy
   if val_acc > best_val_acc:

        best_val_acc = val_acc
        best_epoch = epoch

        torch.save(
            model.state_dict(),
            os.path.join(
                SAVE_DIR,
                "FlowFlow_GAT.pth"
            )
        )

        joblib.dump(
            scaler,
            os.path.join(
                SAVE_DIR,
                "FlowFlow _scaler.pkl"
            )
        )
   scheduler.step()

   print(
        f"Epoch {epoch:03d}"
        f" | Loss {loss:.4f}"
        f" | Train {train_acc:.4f}"
        f" | Validation {val_acc:.4f}"
   )

end_time = time.time()

training_time = end_time - start_time

print("\n" + "=" * 60)
print(f"Training Time          : {training_time:.2f} seconds")
print(f"Best Epoch             : {best_epoch}")
print(f"Best Validation Acc.   : {best_val_acc:.4f}")
print(f"Model Saved At         : {os.path.join(SAVE_DIR,'FlowFlow_GAT.pth')}")
print(f"Scaler Saved At        : {os.path.join(SAVE_DIR,'FlowFlow_scaler.pklpkl')}")
print("=" * 60)
print("Training Complete.")
# Out:
# Epoch 001 | Loss 0.4575 | Train 0.8133 | Validation 0.8123
# Epoch 002 | Loss 0.4007 | Train 0.8319 | Validation 0.8314
# Epoch 003 | Loss 0.3810 | Train 0.8504 | Validation 0.8498
# Epoch 004 | Loss 0.3568 | Train 0.8497 | Validation 0.8493
# Epoch 005 | Loss 0.3435 | Train 0.8519 | Validation 0.8515
# Epoch 006 | Loss 0.3302 | Train 0.8546 | Validation 0.8543
# Epoch 007 | Loss 0.3239 | Train 0.8562 | Validation 0.8561
# Epoch 008 | Loss 0.3211 | Train 0.8566 | Validation 0.8565
# Epoch 009 | Loss 0.3139 | Train 0.8578 | Validation 0.8579
# Epoch 010 | Loss 0.3114 | Train 0.8596 | Validation 0.8595
# Epoch 011 | Loss 0.3101 | Train 0.8608 | Validation 0.8613
# Epoch 012 | Loss 0.3061 | Train 0.8605 | Validation 0.8610
# Epoch 013 | Loss 0.3038 | Train 0.8669 | Validation 0.8676
# Epoch 014 | Loss 0.3033 | Train 0.8410 | Validation 0.8427
# Epoch 015 | Loss 0.3017 | Train 0.8663 | Validation 0.8670
# Epoch 016 | Loss 0.2991 | Train 0.8672 | Validation 0.8681
# Epoch 017 | Loss 0.2943 | Train 0.8683 | Validation 0.8690
# Epoch 018 | Loss 0.2940 | Train 0.8724 | Validation 0.8725
# Epoch 019 | Loss 0.2928 | Train 0.8754 | Validation 0.8752
# Epoch 020 | Loss 0.2913 | Train 0.8748 | Validation 0.8744
# Epoch 021 | Loss 0.2836 | Train 0.8775 | Validation 0.8777
# Epoch 022 | Loss 0.2808 | Train 0.8782 | Validation 0.8777
# Epoch 023 | Loss 0.2793 | Train 0.8813 | Validation 0.8807
# Epoch 024 | Loss 0.2786 | Train 0.8749 | Validation 0.8751
# Epoch 025 | Loss 0.2779 | Train 0.8767 | Validation 0.8770
# Epoch 026 | Loss 0.2763 | Train 0.8795 | Validation 0.8799
# Epoch 027 | Loss 0.2761 | Train 0.8811 | Validation 0.8812
# Epoch 028 | Loss 0.2747 | Train 0.8830 | Validation 0.8824
# Epoch 029 | Loss 0.2741 | Train 0.8833 | Validation 0.8840
# Epoch 030 | Loss 0.2728 | Train 0.8647 | Validation 0.8643
# Epoch 031 | Loss 0.2722 | Train 0.8811 | Validation 0.8825
# Epoch 032 | Loss 0.2707 | Train 0.8678 | Validation 0.8670
# Epoch 033 | Loss 0.2698 | Train 0.8821 | Validation 0.8830
# Epoch 034 | Loss 0.2705 | Train 0.8976 | Validation 0.8964
# Epoch 035 | Loss 0.2685 | Train 0.8806 | Validation 0.8795
# Epoch 036 | Loss 0.2679 | Train 0.8792 | Validation 0.8773
# Epoch 037 | Loss 0.2678 | Train 0.8921 | Validation 0.8923
# Epoch 038 | Loss 0.2662 | Train 0.8772 | Validation 0.8764
# Epoch 039 | Loss 0.2679 | Train 0.8962 | Validation 0.8964
# Epoch 040 | Loss 0.2652 | Train 0.8809 | Validation 0.8797
# Epoch 041 | Loss 0.2614 | Train 0.8824 | Validation 0.8815
# Epoch 042 | Loss 0.2594 | Train 0.8819 | Validation 0.8805
# Epoch 043 | Loss 0.2587 | Train 0.8837 | Validation 0.8819
# Epoch 044 | Loss 0.2566 | Train 0.8840 | Validation 0.8823
# Epoch 045 | Loss 0.2578 | Train 0.8841 | Validation 0.8827
# Epoch 046 | Loss 0.2557 | Train 0.8834 | Validation 0.8823
# Epoch 047 | Loss 0.2574 | Train 0.8840 | Validation 0.8832
# Epoch 048 | Loss 0.2553 | Train 0.8831 | Validation 0.8824
# Epoch 049 | Loss 0.2552 | Train 0.8831 | Validation 0.8823
# Epoch 050 | Loss 0.2545 | Train 0.8834 | Validation 0.8824
# Epoch 051 | Loss 0.2542 | Train 0.8843 | Validation 0.8834
# Epoch 052 | Loss 0.2551 | Train 0.8850 | Validation 0.8832
# Epoch 053 | Loss 0.2549 | Train 0.8836 | Validation 0.8826
# Epoch 054 | Loss 0.2543 | Train 0.8855 | Validation 0.8841
# Epoch 055 | Loss 0.2529 | Train 0.8861 | Validation 0.8842
# Epoch 056 | Loss 0.2528 | Train 0.8851 | Validation 0.8836
# Epoch 057 | Loss 0.2526 | Train 0.8861 | Validation 0.8845
# Epoch 058 | Loss 0.2526 | Train 0.8865 | Validation 0.8848
# Epoch 059 | Loss 0.2516 | Train 0.8845 | Validation 0.8831
# Epoch 060 | Loss 0.2514 | Train 0.8864 | Validation 0.8847
# Epoch 061 | Loss 0.2495 | Train 0.8857 | Validation 0.8845
# Epoch 062 | Loss 0.2477 | Train 0.8878 | Validation 0.8861
# Epoch 063 | Loss 0.2465 | Train 0.8869 | Validation 0.8854
# Epoch 064 | Loss 0.2466 | Train 0.8877 | Validation 0.8859
# Epoch 065 | Loss 0.2461 | Train 0.8869 | Validation 0.8857
# Epoch 066 | Loss 0.2459 | Train 0.8871 | Validation 0.8855
# Epoch 067 | Loss 0.2451 | Train 0.8856 | Validation 0.8846
# Epoch 068 | Loss 0.2459 | Train 0.8858 | Validation 0.8844
# Epoch 069 | Loss 0.2456 | Train 0.8856 | Validation 0.8838
# Epoch 070 | Loss 0.2463 | Train 0.8859 | Validation 0.8846
# Epoch 071 | Loss 0.2444 | Train 0.8881 | Validation 0.8867
# Epoch 072 | Loss 0.2449 | Train 0.8877 | Validation 0.8863
# Epoch 073 | Loss 0.2441 | Train 0.8867 | Validation 0.8849
# Epoch 074 | Loss 0.2445 | Train 0.8869 | Validation 0.8855
# Epoch 075 | Loss 0.2448 | Train 0.8862 | Validation 0.8850
# Epoch 076 | Loss 0.2446 | Train 0.8882 | Validation 0.8866
# Epoch 077 | Loss 0.2440 | Train 0.8865 | Validation 0.8853
# Epoch 078 | Loss 0.2440 | Train 0.8859 | Validation 0.8848
# Epoch 079 | Loss 0.2437 | Train 0.8865 | Validation 0.8849
# Epoch 080 | Loss 0.2444 | Train 0.8872 | Validation 0.8851
# Epoch 081 | Loss 0.2423 | Train 0.8888 | Validation 0.8868
# Epoch 082 | Loss 0.2415 | Train 0.8888 | Validation 0.8870
# Epoch 083 | Loss 0.2418 | Train 0.8888 | Validation 0.8871
# Epoch 084 | Loss 0.2405 | Train 0.8867 | Validation 0.8850
# Epoch 085 | Loss 0.2411 | Train 0.8889 | Validation 0.8874
# Epoch 086 | Loss 0.2408 | Train 0.8890 | Validation 0.8874
# Epoch 087 | Loss 0.2403 | Train 0.8890 | Validation 0.8872
# Epoch 088 | Loss 0.2408 | Train 0.8878 | Validation 0.8863
# Epoch 089 | Loss 0.2406 | Train 0.8878 | Validation 0.8860
# Epoch 090 | Loss 0.2393 | Train 0.8878 | Validation 0.8862
# Epoch 091 | Loss 0.2392 | Train 0.8882 | Validation 0.8866
# Epoch 092 | Loss 0.2394 | Train 0.8893 | Validation 0.8878
# Epoch 093 | Loss 0.2410 | Train 0.8874 | Validation 0.8860
# Epoch 094 | Loss 0.2402 | Train 0.8879 | Validation 0.8865
# Epoch 095 | Loss 0.2395 | Train 0.8903 | Validation 0.8887
# Epoch 096 | Loss 0.2391 | Train 0.8892 | Validation 0.8872
# Epoch 097 | Loss 0.2388 | Train 0.8880 | Validation 0.8864
# Epoch 098 | Loss 0.2393 | Train 0.8893 | Validation 0.8871
# Epoch 099 | Loss 0.2389 | Train 0.8889 | Validation 0.8873
# Epoch 100 | Loss 0.2393 | Train 0.8895 | Validation 0.8878
# Epoch 101 | Loss 0.2384 | Train 0.8878 | Validation 0.8861
# Epoch 102 | Loss 0.2379 | Train 0.8884 | Validation 0.8872
# Epoch 103 | Loss 0.2366 | Train 0.8893 | Validation 0.8879
# Epoch 104 | Loss 0.2370 | Train 0.8891 | Validation 0.8875
# Epoch 105 | Loss 0.2377 | Train 0.8885 | Validation 0.8875
# Epoch 106 | Loss 0.2370 | Train 0.8894 | Validation 0.8877
# Epoch 107 | Loss 0.2371 | Train 0.8888 | Validation 0.8874
# Epoch 108 | Loss 0.2377 | Train 0.8895 | Validation 0.8881
# Epoch 109 | Loss 0.2369 | Train 0.8891 | Validation 0.8876
# Epoch 110 | Loss 0.2395 | Train 0.8881 | Validation 0.8864
# Epoch 111 | Loss 0.2378 | Train 0.8902 | Validation 0.8888
# Epoch 112 | Loss 0.2367 | Train 0.8885 | Validation 0.8872
# Epoch 113 | Loss 0.2379 | Train 0.8888 | Validation 0.8871
# Epoch 114 | Loss 0.2376 | Train 0.8880 | Validation 0.8865
# Epoch 115 | Loss 0.2366 | Train 0.8888 | Validation 0.8878
# Epoch 116 | Loss 0.2377 | Train 0.8904 | Validation 0.8889
# Epoch 117 | Loss 0.2367 | Train 0.8897 | Validation 0.8881
# Epoch 118 | Loss 0.2361 | Train 0.8890 | Validation 0.8875
# Epoch 119 | Loss 0.2362 | Train 0.8903 | Validation 0.8887
# Epoch 120 | Loss 0.2369 | Train 0.8888 | Validation 0.8872
# Epoch 121 | Loss 0.2363 | Train 0.8902 | Validation 0.8887
# Epoch 122 | Loss 0.2363 | Train 0.8898 | Validation 0.8881
# Epoch 123 | Loss 0.2359 | Train 0.8901 | Validation 0.8887
# Epoch 124 | Loss 0.2355 | Train 0.8905 | Validation 0.8887
# Epoch 125 | Loss 0.2351 | Train 0.8898 | Validation 0.8882
# Epoch 126 | Loss 0.2359 | Train 0.8892 | Validation 0.8876
# Epoch 127 | Loss 0.2358 | Train 0.8888 | Validation 0.8874
# Epoch 128 | Loss 0.2355 | Train 0.8899 | Validation 0.8884
# Epoch 129 | Loss 0.2350 | Train 0.8908 | Validation 0.8894
# Epoch 130 | Loss 0.2361 | Train 0.8904 | Validation 0.8891
# Epoch 131 | Loss 0.2351 | Train 0.8902 | Validation 0.8886
# Epoch 132 | Loss 0.2359 | Train 0.8906 | Validation 0.8889
# Epoch 133 | Loss 0.2350 | Train 0.8903 | Validation 0.8889
# Epoch 134 | Loss 0.2355 | Train 0.8892 | Validation 0.8878
# Epoch 135 | Loss 0.2353 | Train 0.8903 | Validation 0.8890
# Epoch 136 | Loss 0.2353 | Train 0.8900 | Validation 0.8884
# Epoch 137 | Loss 0.2357 | Train 0.8908 | Validation 0.8889
# Epoch 138 | Loss 0.2352 | Train 0.8904 | Validation 0.8888
# Epoch 139 | Loss 0.2348 | Train 0.8907 | Validation 0.8892
# Epoch 140 | Loss 0.2349 | Train 0.8907 | Validation 0.8893
# Epoch 141 | Loss 0.2347 | Train 0.8906 | Validation 0.8893
# Epoch 142 | Loss 0.2350 | Train 0.8895 | Validation 0.8880
# Epoch 143 | Loss 0.2345 | Train 0.8907 | Validation 0.8889
# Epoch 144 | Loss 0.2345 | Train 0.8905 | Validation 0.8889
# Epoch 145 | Loss 0.2352 | Train 0.8903 | Validation 0.8890
# Epoch 146 | Loss 0.2344 | Train 0.8894 | Validation 0.8882
# Epoch 147 | Loss 0.2348 | Train 0.8911 | Validation 0.8898
# Epoch 148 | Loss 0.2346 | Train 0.8907 | Validation 0.8894
# Epoch 149 | Loss 0.2354 | Train 0.8891 | Validation 0.8879
# Epoch 150 | Loss 0.2352 | Train 0.8899 | Validation 0.8885
#
# ============================================================
# Training Time          : 2849.72 seconds
# Best Epoch             : 34
# Best Validation Acc.   : 0.8964
# Model Saved At         : /Users/balji/OneDrive/GNN_IDS/Saved_Model\FlowFlow_GAT.pth
# Scaler Saved At        : /Users/balji/OneDrive/GNN_IDS/Saved_Model\FlowFlow _scaler.pklpkl
# ============================================================
# Training Complete.

# %%
import time
import torch

print("=" * 60)

# Training Time
print(f"Training Time: {training_time:.2f} seconds ({150} epochs)\n")

# GPU Memory
if torch.cuda.is_available():

    allocated = torch.cuda.memory_allocated() / (1024 ** 2)
    reserved = torch.cuda.memory_reserved() / (1024 ** 2)
    max_reserved = torch.cuda.max_memory_reserved() / (1024 ** 2)

    print(f"Allocated GPU Memory: {allocated:.2f} MB")
    print(f"Reserved GPU Memory: {reserved:.2f} MB")
    print(f"Max GPU Memory: {max_reserved:.2f} MB\n")

# Model Parameters
total_params = sum(
    p.numel() for p in model.parameters()
)

trainable_params = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print(f"Total Parameters: {total_params}")
print(f"Trainable Parameters: {trainable_params}\n")

# Graph Memory
node_memory = (
    graph.x.element_size()
    * graph.x.nelement()
) / (1024 ** 2)

edge_memory = (
    graph.edge_index.element_size()
    * graph.edge_index.nelement()
) / (1024 ** 2)

graph_memory = node_memory + edge_memory

print(f"Node Feature Memory: {node_memory:.2f} MB")
print(f"Edge Memory: {edge_memory:.2f} MB")
print(f"Total Graph Memory: {graph_memory:.2f} MB")

print("=" * 60)
# Out:
# ============================================================
# Training Time: 2849.72 seconds (150 epochs)
#
# Allocated GPU Memory: 139.33 MB
# Reserved GPU Memory: 3910.00 MB
# Max GPU Memory: 3910.00 MB
#
# Total Parameters: 216066
# Trainable Parameters: 216066
#
# Node Feature Memory: 45.78 MB
# Edge Memory: 68.96 MB
# Total Graph Memory: 114.74 MB
# ============================================================
