# %% [markdown]
# <a href="https://colab.research.google.com/github/SAINIDHI2005/IDS_GNN_Repo/blob/main/HostFlow_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch-geometric -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 39.7 MB/s eta 0:00:00

# %%
import os

import pandas as pd
import numpy as np

import torch

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from torch_geometric.data import Data

# %%
DATASET_DIR = "/content/drive/MyDrive/CIC_IoT_2023/Host_flow_temporal"

files = {
    "BENIGN.csv":0,
    "DDoS.csv":1,
    "DoS.csv":1,
    "Mirai.csv":1,
    "Recon.csv":1,
    "Spoofing.csv":1
}

dfs = []

for file,label in files.items():

    path = os.path.join(DATASET_DIR,file)

    df = pd.read_csv(path)

    attack_name = file.replace(".csv","")

    df["attack_type"] = attack_name

    df["label"] = label

    dfs.append(df)

data = pd.concat(
    dfs,
    ignore_index=True
)

print(data.shape)

print(data["attack_type"].value_counts())
# Out:
# (400000, 88)
# attack_type
# BENIGN      200000
# DDoS         40000
# DoS          40000
# Mirai        40000
# Recon        40000
# Spoofing     40000
# Name: count, dtype: int64

# %%
data = data.sort_values(
    "bidirectional_first_seen_ms"
).reset_index(drop=True)

data["flow_id"] = np.arange(len(data))

print(data.shape)
# Out:
# (400000, 89)

# %%
attack_type_backup = data["attack_type"].copy()

# %%
DROP_COLS = [

    "id",
    "expiration_id",

    "src_ip",
    "dst_ip",

    "src_mac",
    "dst_mac",

    "src_oui",
    "dst_oui",

    "requested_server_name",

    "client_fingerprint",
    "server_fingerprint",

    "user_agent",
    "content_type",

    "application_name",
    "application_category_name",

    "flow_id",
    "label",
    "attack_type",

    "bidirectional_first_seen_ms",
    "bidirectional_last_seen_ms",

    "src2dst_first_seen_ms",
    "src2dst_last_seen_ms",

    "dst2src_first_seen_ms",
    "dst2src_last_seen_ms",

    "application_confidence",
    "application_is_guessed",

    "vlan_id",
    "tunnel_id",

    "bidirectional_urg_packets",
    "src2dst_urg_packets",
    "dst2src_urg_packets",

    "dst2src_cwr_packets",
    "dst2src_ece_packets",

    "src_port",

    "bidirectional_duration_ms",
    "bidirectional_packets",

    "src2dst_packets",
    "dst2src_packets",

    "dst2src_min_ps",
    "dst2src_mean_ps",

    "bidirectional_min_piat_ms",
    "bidirectional_stddev_piat_ms",

    "dst2src_min_piat_ms",
    "dst2src_mean_piat_ms",
    "dst2src_max_piat_ms",

    "bidirectional_ece_packets",
    "bidirectional_psh_packets",
    "bidirectional_fin_packets",

    "src2dst_syn_packets",
    "src2dst_cwr_packets",
    "src2dst_ack_packets",
    "src2dst_rst_packets",
    "src2dst_fin_packets",

    "src2dst_mean_piat_ms",
    "src2dst_stddev_ps",

    "dst2src_ack_packets",
    "dst2src_psh_packets",
    "dst2src_rst_packets",
    "dst2src_fin_packets",

]

feature_cols = [

    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:",len(feature_cols))
# Out:
# Features: 30

# %%
feature_cols = [
    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:", len(feature_cols))

print("\nRetained Features:\n")
for i, f in enumerate(feature_cols, start=1):
    print(f"{i:2d}. {f}")
# Out:
# Features: 30
#
# Retained Features:
#
#  1. dst_port
#  2. protocol
#  3. ip_version
#  4. bidirectional_bytes
#  5. src2dst_duration_ms
#  6. src2dst_bytes
#  7. dst2src_duration_ms
#  8. dst2src_bytes
#  9. bidirectional_min_ps
# 10. bidirectional_mean_ps
# 11. bidirectional_stddev_ps
# 12. bidirectional_max_ps
# 13. src2dst_min_ps
# 14. src2dst_mean_ps
# 15. src2dst_max_ps
# 16. dst2src_stddev_ps
# 17. dst2src_max_ps
# 18. bidirectional_mean_piat_ms
# 19. bidirectional_max_piat_ms
# 20. src2dst_min_piat_ms
# 21. src2dst_stddev_piat_ms
# 22. src2dst_max_piat_ms
# 23. dst2src_stddev_piat_ms
# 24. bidirectional_syn_packets
# 25. bidirectional_cwr_packets
# 26. bidirectional_ack_packets
# 27. bidirectional_rst_packets
# 28. src2dst_ece_packets
# 29. src2dst_psh_packets
# 30. dst2src_syn_packets

# %%
top30 = {
    "bidirectional_mean_ps",
    "dst2src_syn_packets",
    "src2dst_min_ps",
    "ip_version",
    "src2dst_max_piat_ms",
    "dst2src_stddev_piat_ms",
    "bidirectional_max_piat_ms",
    "bidirectional_rst_packets",
    "src2dst_max_ps",
    "src2dst_duration_ms",
    "src2dst_bytes",
    "src2dst_ece_packets",
    "bidirectional_max_ps",
    "dst2src_bytes",
    "bidirectional_bytes",
    "dst2src_max_ps",
    "bidirectional_min_ps",
    "bidirectional_syn_packets",
    "dst2src_stddev_ps",
    "bidirectional_ack_packets",
    "protocol",
    "dst_port",
    "bidirectional_mean_piat_ms",
    "dst2src_duration_ms",
    "src2dst_mean_ps",
    "src2dst_min_piat_ms",
    "bidirectional_stddev_ps",
    "src2dst_stddev_piat_ms",
    "bidirectional_cwr_packets",
    "src2dst_psh_packets"
}

retained = set(feature_cols)

print("Missing from retained:")
print(sorted(top30 - retained))

print("\nExtra retained features:")
print(sorted(retained - top30))
# Out:
# Missing from retained:
# []
#
# Extra retained features:
# []

# %%
for col in feature_cols:

    data[col] = pd.to_numeric(
        data[col],
        errors="coerce"
    )

data[feature_cols] = (
    data[feature_cols]
    .fillna(0)
)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(
    data[feature_cols]
)

print(X.shape)
# Out:
# (400000, 30)

# %%
all_hosts = pd.concat(
    [
        data["src_ip"],
        data["dst_ip"]
    ]
).unique()

host_to_id = {

    host : idx + len(data)

    for idx,host
    in enumerate(all_hosts)
}

num_flow_nodes = len(data)

num_host_nodes = len(all_hosts)

print("Flow Nodes:",num_flow_nodes)
print("Host Nodes:",num_host_nodes)
# Out:
# Flow Nodes: 400000
# Host Nodes: 4572

# %%
edges = []

for flow_id,row in data.iterrows():

    src_host = host_to_id[
        row["src_ip"]
    ]

    dst_host = host_to_id[
        row["dst_ip"]
    ]

    edges.append(
        [flow_id,src_host]
    )

    edges.append(
        [src_host,flow_id]
    )

    edges.append(
        [flow_id,dst_host]
    )

    edges.append(
        [dst_host,flow_id]
    )

print("Host-flow edges built")
# Out:
# Host-flow edges built

# %%
src_groups = data.groupby(
    "src_ip"
)["flow_id"].apply(list)

print(
    "Groups:",
    len(src_groups)
)
# Out:
# Groups: 1303

# %%
edge_index = torch.tensor(
    edges,
    dtype=torch.long
).t().contiguous()

print(edge_index.shape)
# Out:
# torch.Size([2, 1600000])

# %%
flow_features = torch.tensor(
    X,
    dtype=torch.float
)

# %%
host_features = torch.zeros(

    (
        num_host_nodes,
        flow_features.shape[1]
    ),

    dtype=torch.float
)

host_counts = np.zeros(
    num_host_nodes
)

for flow_id,row in data.iterrows():

    src_idx = (
        host_to_id[
            row["src_ip"]
        ]
        -
        num_flow_nodes
    )

    dst_idx = (
        host_to_id[
            row["dst_ip"]
        ]
        -
        num_flow_nodes
    )

    host_features[src_idx] += flow_features[flow_id]
    host_features[dst_idx] += flow_features[flow_id]

    host_counts[src_idx] += 1
    host_counts[dst_idx] += 1

for i in range(num_host_nodes):

    if host_counts[i] > 0:

        host_features[i] /= (
            host_counts[i]
        )

# %%
x = torch.cat(
    [
        flow_features,
        host_features
    ],
    dim=0
)

print(x.shape)
# Out:
# torch.Size([404572, 30])

# %%
flow_labels = torch.tensor(
    data["label"].values,
    dtype=torch.long
)

host_labels = torch.full(
    (
        num_host_nodes,
    ),
    -1,
    dtype=torch.long
)

y = torch.cat(
    [
        flow_labels,
        host_labels
    ]
)

print(y.shape)
# Out:
# torch.Size([404572])

# %%
flow_hosts = (
    data["src_ip"].astype(str)
    + "_"
    + data["dst_ip"].astype(str)
)

unique_pairs = flow_hosts.unique()

train_pairs, val_pairs = train_test_split(
    unique_pairs,
    test_size=0.2,
    random_state=42
)

train_idx = data[
    flow_hosts.isin(train_pairs)
].index.values

val_idx = data[
    flow_hosts.isin(val_pairs)
].index.values

print("Train flows :", len(train_idx))
print("Validation flows :", len(val_idx))

print("Train pairs :", len(train_pairs))
print("Validation pairs :", len(val_pairs))
# Out:
# Train flows : 313475
# Validation flows : 86525
# Train pairs : 9756
# Validation pairs : 2439

# %%
total_nodes = (
    num_flow_nodes
    +
    num_host_nodes
)

train_mask = torch.zeros(
    total_nodes,
    dtype=torch.bool
)

val_mask = torch.zeros(
    total_nodes,
    dtype=torch.bool
)

train_mask[train_idx] = True
val_mask[val_idx] = True

print("Train mask      :", train_mask.sum().item())
print("Validation mask :", val_mask.sum().item())
# Out:
# Train mask      : 313475
# Validation mask : 86525

# %%
graph = Data(
    x=x,
    edge_index=edge_index,
    y=y,
    train_mask=train_mask,
    val_mask=val_mask
)

print(graph)

print(
    "Nodes:",
    graph.num_nodes
)

print(
    "Edges:",
    graph.num_edges
)
# Out:
# Data(x=[404572, 30], edge_index=[2, 1600000], y=[404572], train_mask=[404572], val_mask=[404572])
# Nodes: 404572
# Edges: 1600000

# %%
import torch
import torch.nn.functional as F

from torch_geometric.nn import SAGEConv

class GraphSAGE(torch.nn.Module):

    def __init__(
        self,
        in_channels,
        hidden_channels,
        num_classes
    ):

        super().__init__()

        self.conv1 = SAGEConv(
            in_channels,
            hidden_channels
        )

        self.conv2 = SAGEConv(
            hidden_channels,
            hidden_channels
        )

        self.conv3 = SAGEConv(
            hidden_channels,
            hidden_channels // 2
        )

        self.bn1 = torch.nn.BatchNorm1d(
            hidden_channels
        )

        self.bn2 = torch.nn.BatchNorm1d(
            hidden_channels
        )

        self.bn3 = torch.nn.BatchNorm1d(
            hidden_channels // 2
        )

        self.classifier = torch.nn.Linear(
            hidden_channels // 2,
            num_classes
        )

    def forward(
        self,
        x,
        edge_index
    ):

        x = self.conv1(
            x,
            edge_index
        )

        x = self.bn1(x)

        x = F.relu(x)

        x = F.dropout(
            x,
            p=0.4,
            training=self.training
        )

        x = self.conv2(
            x,
            edge_index
        )

        x = self.bn2(x)

        x = F.relu(x)

        x = F.dropout(
            x,
            p=0.4,
            training=self.training
        )

        x = self.conv3(
            x,
            edge_index
        )

        x = self.bn3(x)

        x = F.relu(x)

        x = self.classifier(x)

        return x

# %%
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print(device)
# Out:
# cuda

# %%
model = GraphSAGE(
    in_channels=graph.num_node_features,
    hidden_channels=256,
    num_classes=2
)

model = model.to(device)

graph = graph.to(device)

print(model)
# Out:
# GraphSAGE(
#   (conv1): SAGEConv(30, 256, aggr=mean)
#   (conv2): SAGEConv(256, 256, aggr=mean)
#   (conv3): SAGEConv(256, 128, aggr=mean)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.001,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=20,
    gamma=0.5
)

# %%
weights = torch.tensor(
    [1.0, 1.5],
    dtype=torch.float
).to(device)

criterion = torch.nn.CrossEntropyLoss(
    weight=weights
)

# %%
def train():

    model.train()

    optimizer.zero_grad()

    out = model(
        graph.x,
        graph.edge_index
    )

    loss = criterion(
        out[graph.train_mask],
        graph.y[graph.train_mask]
    )

    loss.backward()

    optimizer.step()

    return loss.item()

# %%
@torch.no_grad()

def evaluate(mask):

    model.eval()

    out = model(
        graph.x,
        graph.edge_index
    )

    pred = out.argmax(
        dim=1
    )

    correct = (
        pred[mask]
        ==
        graph.y[mask]
    ).sum()

    acc = (
        correct.item()
        /
        mask.sum().item()
    )

    return acc

# %%
import time

start_time = time.time()

if torch.cuda.is_available():
    torch.cuda.reset_peak_memory_stats()

# %%
import os
import torch
import joblib

SAVE_DIR = "/content/drive/MyDrive/CIC_IoT_2023/Saved_Model"
os.makedirs(SAVE_DIR, exist_ok=True)

MODEL_NAME = "HostFlow"      # Change to HostFlow, FlowFlow, HostFlowTemporal etc.

best_val_acc = 0.0
best_epoch = 0

for epoch in range(1, 151):

    loss = train()

    train_acc = evaluate(
        graph.train_mask
    )

    val_acc = evaluate(
        graph.val_mask
    )

    # Save best model based on validation accuracy
    if val_acc > best_val_acc:

        best_val_acc = val_acc
        best_epoch = epoch



    print(
        f"Epoch {epoch:03d}"
        f" | Loss {loss:.4f}"
        f" | Train {train_acc:.4f}"
        f" | Validation {val_acc:.4f}"
    )

training_time = time.time() - start_time
print("\n" + "="*60)
print(f"Best Validation Accuracy : {best_val_acc:.4f}")
print(f"Best Epoch               : {best_epoch}")
print(f"Model Saved At           : {SAVE_DIR}/{MODEL_NAME}_graphSAGE.pth")
print(f"Scaler Saved At          : {SAVE_DIR}/{MODEL_NAME}_scaler.pkl")
print("="*60)
# Out:
# Epoch 001 | Loss 0.7405 | Train 0.7837 | Validation 0.4872
# Epoch 002 | Loss 0.5921 | Train 0.7813 | Validation 0.8021
# Epoch 003 | Loss 0.5473 | Train 0.7819 | Validation 0.8051
# Epoch 004 | Loss 0.5050 | Train 0.7791 | Validation 0.8045
# Epoch 005 | Loss 0.4801 | Train 0.7871 | Validation 0.7967
# Epoch 006 | Loss 0.4586 | Train 0.7899 | Validation 0.8001
# Epoch 007 | Loss 0.4412 | Train 0.7993 | Validation 0.8076
# Epoch 008 | Loss 0.4162 | Train 0.8008 | Validation 0.8124
# Epoch 009 | Loss 0.4012 | Train 0.8152 | Validation 0.8135
# Epoch 010 | Loss 0.4011 | Train 0.8196 | Validation 0.8122
# Epoch 011 | Loss 0.3772 | Train 0.8230 | Validation 0.8110
# Epoch 012 | Loss 0.3753 | Train 0.8267 | Validation 0.8135
# Epoch 013 | Loss 0.3564 | Train 0.8314 | Validation 0.8145
# Epoch 014 | Loss 0.3565 | Train 0.8345 | Validation 0.8171
# Epoch 015 | Loss 0.3432 | Train 0.8449 | Validation 0.8216
# Epoch 016 | Loss 0.3317 | Train 0.8523 | Validation 0.8243
# Epoch 017 | Loss 0.3322 | Train 0.8559 | Validation 0.8252
# Epoch 018 | Loss 0.3149 | Train 0.8599 | Validation 0.8258
# Epoch 019 | Loss 0.3172 | Train 0.8635 | Validation 0.8291
# Epoch 020 | Loss 0.3013 | Train 0.8662 | Validation 0.8317
# Epoch 021 | Loss 0.2996 | Train 0.8711 | Validation 0.8375
# Epoch 022 | Loss 0.2869 | Train 0.8826 | Validation 0.8388
# Epoch 023 | Loss 0.2769 | Train 0.8848 | Validation 0.8403
# Epoch 024 | Loss 0.2693 | Train 0.9028 | Validation 0.8422
# Epoch 025 | Loss 0.2656 | Train 0.9124 | Validation 0.8430
# Epoch 026 | Loss 0.2525 | Train 0.9152 | Validation 0.8448
# Epoch 027 | Loss 0.2622 | Train 0.9152 | Validation 0.8452
# Epoch 028 | Loss 0.2452 | Train 0.9123 | Validation 0.8455
# Epoch 029 | Loss 0.2465 | Train 0.9135 | Validation 0.8462
# Epoch 030 | Loss 0.2248 | Train 0.9158 | Validation 0.8468
# Epoch 031 | Loss 0.2262 | Train 0.9212 | Validation 0.8478
# Epoch 032 | Loss 0.2301 | Train 0.9251 | Validation 0.8489
# Epoch 033 | Loss 0.2316 | Train 0.9247 | Validation 0.8494
# Epoch 034 | Loss 0.2268 | Train 0.9257 | Validation 0.8500
# Epoch 035 | Loss 0.2273 | Train 0.9275 | Validation 0.8504
# Epoch 036 | Loss 0.2177 | Train 0.9275 | Validation 0.8508
# Epoch 037 | Loss 0.2200 | Train 0.9286 | Validation 0.8516
# Epoch 038 | Loss 0.2048 | Train 0.9299 | Validation 0.8522
# Epoch 039 | Loss 0.2293 | Train 0.9299 | Validation 0.8522
# Epoch 040 | Loss 0.2120 | Train 0.9300 | Validation 0.8542
# Epoch 041 | Loss 0.2033 | Train 0.9301 | Validation 0.8537
# Epoch 042 | Loss 0.1911 | Train 0.9312 | Validation 0.8758
# Epoch 043 | Loss 0.2165 | Train 0.9332 | Validation 0.8777
# Epoch 044 | Loss 0.1807 | Train 0.9342 | Validation 0.8796
# Epoch 045 | Loss 0.2047 | Train 0.9325 | Validation 0.8770
# Epoch 046 | Loss 0.1895 | Train 0.9321 | Validation 0.8743
# Epoch 047 | Loss 0.1891 | Train 0.9336 | Validation 0.8800
# Epoch 048 | Loss 0.1761 | Train 0.9389 | Validation 0.8871
# Epoch 049 | Loss 0.1821 | Train 0.9410 | Validation 0.8903
# Epoch 050 | Loss 0.1784 | Train 0.9434 | Validation 0.8923
# Epoch 051 | Loss 0.1760 | Train 0.9445 | Validation 0.8929
# Epoch 052 | Loss 0.1903 | Train 0.9395 | Validation 0.8940
# Epoch 053 | Loss 0.1749 | Train 0.9370 | Validation 0.8944
# Epoch 054 | Loss 0.1787 | Train 0.9364 | Validation 0.8930
# Epoch 055 | Loss 0.1868 | Train 0.9412 | Validation 0.8980
# Epoch 056 | Loss 0.1803 | Train 0.9454 | Validation 0.9080
# Epoch 057 | Loss 0.1670 | Train 0.9455 | Validation 0.9087
# Epoch 058 | Loss 0.1711 | Train 0.9460 | Validation 0.9042
# Epoch 059 | Loss 0.1586 | Train 0.9464 | Validation 0.9031
# Epoch 060 | Loss 0.1608 | Train 0.9464 | Validation 0.9023
# Epoch 061 | Loss 0.1618 | Train 0.9408 | Validation 0.9022
# Epoch 062 | Loss 0.1609 | Train 0.9496 | Validation 0.9031
# Epoch 063 | Loss 0.1632 | Train 0.9533 | Validation 0.9034
# Epoch 064 | Loss 0.1671 | Train 0.9530 | Validation 0.9035
# Epoch 065 | Loss 0.1624 | Train 0.9536 | Validation 0.9044
# Epoch 066 | Loss 0.1773 | Train 0.9488 | Validation 0.9057
# Epoch 067 | Loss 0.1573 | Train 0.9488 | Validation 0.9023
# Epoch 068 | Loss 0.1597 | Train 0.9477 | Validation 0.9034
# Epoch 069 | Loss 0.1562 | Train 0.9501 | Validation 0.9044
# Epoch 070 | Loss 0.1726 | Train 0.9510 | Validation 0.9004
# Epoch 071 | Loss 0.1615 | Train 0.9518 | Validation 0.9124
# Epoch 072 | Loss 0.1577 | Train 0.9562 | Validation 0.9120
# Epoch 073 | Loss 0.1446 | Train 0.9570 | Validation 0.9208
# Epoch 074 | Loss 0.1430 | Train 0.9574 | Validation 0.9097
# Epoch 075 | Loss 0.1492 | Train 0.9584 | Validation 0.9007
# Epoch 076 | Loss 0.1539 | Train 0.9574 | Validation 0.9008
# Epoch 077 | Loss 0.1641 | Train 0.9531 | Validation 0.9013
# Epoch 078 | Loss 0.1597 | Train 0.9544 | Validation 0.9060
# Epoch 079 | Loss 0.1474 | Train 0.9527 | Validation 0.9130
# Epoch 080 | Loss 0.1497 | Train 0.9528 | Validation 0.9132
# Epoch 081 | Loss 0.1496 | Train 0.9539 | Validation 0.9134
# Epoch 082 | Loss 0.1347 | Train 0.9590 | Validation 0.9142
# Epoch 083 | Loss 0.1451 | Train 0.9601 | Validation 0.9097
# Epoch 084 | Loss 0.1410 | Train 0.9597 | Validation 0.9082
# Epoch 085 | Loss 0.1444 | Train 0.9596 | Validation 0.9047
# Epoch 086 | Loss 0.1482 | Train 0.9599 | Validation 0.9121
# Epoch 087 | Loss 0.1553 | Train 0.9604 | Validation 0.9091
# Epoch 088 | Loss 0.1378 | Train 0.9610 | Validation 0.9105
# Epoch 089 | Loss 0.1387 | Train 0.9583 | Validation 0.9137
# Epoch 090 | Loss 0.1339 | Train 0.9575 | Validation 0.9154
# Epoch 091 | Loss 0.1393 | Train 0.9570 | Validation 0.9167
# Epoch 092 | Loss 0.1377 | Train 0.9575 | Validation 0.9170
# Epoch 093 | Loss 0.1440 | Train 0.9594 | Validation 0.9157
# Epoch 094 | Loss 0.1424 | Train 0.9618 | Validation 0.9102
# Epoch 095 | Loss 0.1329 | Train 0.9619 | Validation 0.9099
# Epoch 096 | Loss 0.1418 | Train 0.9622 | Validation 0.9178
# Epoch 097 | Loss 0.1394 | Train 0.9610 | Validation 0.9180
# Epoch 098 | Loss 0.1364 | Train 0.9607 | Validation 0.9201
# Epoch 099 | Loss 0.1398 | Train 0.9619 | Validation 0.9187
# Epoch 100 | Loss 0.1313 | Train 0.9621 | Validation 0.9116
# Epoch 101 | Loss 0.1402 | Train 0.9596 | Validation 0.9119
# Epoch 102 | Loss 0.1277 | Train 0.9582 | Validation 0.9121
# Epoch 103 | Loss 0.1376 | Train 0.9580 | Validation 0.9125
# Epoch 104 | Loss 0.1363 | Train 0.9585 | Validation 0.9138
# Epoch 105 | Loss 0.1340 | Train 0.9630 | Validation 0.9117
# Epoch 106 | Loss 0.1353 | Train 0.9647 | Validation 0.9124
# Epoch 107 | Loss 0.1205 | Train 0.9658 | Validation 0.9125
# Epoch 108 | Loss 0.1268 | Train 0.9651 | Validation 0.9118
# Epoch 109 | Loss 0.1283 | Train 0.9653 | Validation 0.9122
# Epoch 110 | Loss 0.1259 | Train 0.9645 | Validation 0.9118
# Epoch 111 | Loss 0.1316 | Train 0.9653 | Validation 0.9115
# Epoch 112 | Loss 0.1261 | Train 0.9659 | Validation 0.9179
# Epoch 113 | Loss 0.1290 | Train 0.9662 | Validation 0.9116
# Epoch 114 | Loss 0.1345 | Train 0.9673 | Validation 0.9123
# Epoch 115 | Loss 0.1265 | Train 0.9670 | Validation 0.9124
# Epoch 116 | Loss 0.1300 | Train 0.9667 | Validation 0.9122
# Epoch 117 | Loss 0.1232 | Train 0.9666 | Validation 0.9126
# Epoch 118 | Loss 0.1187 | Train 0.9665 | Validation 0.9125
# Epoch 119 | Loss 0.1311 | Train 0.9665 | Validation 0.9187
# Epoch 120 | Loss 0.1297 | Train 0.9672 | Validation 0.9120
# Epoch 121 | Loss 0.1289 | Train 0.9677 | Validation 0.9154
# Epoch 122 | Loss 0.1211 | Train 0.9673 | Validation 0.9151
# Epoch 123 | Loss 0.1233 | Train 0.9674 | Validation 0.9147
# Epoch 124 | Loss 0.1211 | Train 0.9678 | Validation 0.9215
# Epoch 125 | Loss 0.1361 | Train 0.9629 | Validation 0.9123
# Epoch 126 | Loss 0.1246 | Train 0.9624 | Validation 0.9127
# Epoch 127 | Loss 0.1222 | Train 0.9617 | Validation 0.9129
# Epoch 128 | Loss 0.1341 | Train 0.9622 | Validation 0.9126
# Epoch 129 | Loss 0.1334 | Train 0.9633 | Validation 0.9124
# Epoch 130 | Loss 0.1211 | Train 0.9669 | Validation 0.9227
# Epoch 131 | Loss 0.1238 | Train 0.9655 | Validation 0.9294
# Epoch 132 | Loss 0.1161 | Train 0.9661 | Validation 0.9294
# Epoch 133 | Loss 0.1277 | Train 0.9675 | Validation 0.9310
# Epoch 134 | Loss 0.1382 | Train 0.9689 | Validation 0.9149
# Epoch 135 | Loss 0.1165 | Train 0.9596 | Validation 0.9138
# Epoch 136 | Loss 0.1440 | Train 0.9604 | Validation 0.9141
# Epoch 137 | Loss 0.1258 | Train 0.9632 | Validation 0.9126
# Epoch 138 | Loss 0.1401 | Train 0.9642 | Validation 0.9170
# Epoch 139 | Loss 0.1421 | Train 0.9638 | Validation 0.9178
# Epoch 140 | Loss 0.1246 | Train 0.9687 | Validation 0.9244
# Epoch 141 | Loss 0.1207 | Train 0.9689 | Validation 0.9381
# Epoch 142 | Loss 0.1315 | Train 0.9689 | Validation 0.9373
# Epoch 143 | Loss 0.2011 | Train 0.9682 | Validation 0.9168
# Epoch 144 | Loss 0.1287 | Train 0.9633 | Validation 0.9146
# Epoch 145 | Loss 0.1327 | Train 0.9573 | Validation 0.9122
# Epoch 146 | Loss 0.1440 | Train 0.9606 | Validation 0.9124
# Epoch 147 | Loss 0.1464 | Train 0.9609 | Validation 0.9130
# Epoch 148 | Loss 0.1348 | Train 0.9624 | Validation 0.9168
# Epoch 149 | Loss 0.1287 | Train 0.9625 | Validation 0.9174
# Epoch 150 | Loss 0.1412 | Train 0.9665 | Validation 0.9165
#
# ============================================================
# Best Validation Accuracy : 0.9381
# Best Epoch               : 141
# Model Saved At           : /content/drive/MyDrive/CIC_IoT_2023/Saved_Model/HostFlow_graphSAGE.pth
# Scaler Saved At          : /content/drive/MyDrive/CIC_IoT_2023/Saved_Model/HostFlow_scaler.pkl
# ============================================================

# %%
import time
import torch

print("=" * 60)

# Training Time
print(f"Training Time: {training_time:.2f} seconds ({150} epochs)\n")

# GPU Memory
if torch.cuda.is_available():

    allocated = torch.cuda.memory_allocated() / (1024 ** 2)
    reserved = torch.cuda.memory_reserved() / (1024 ** 2)
    max_reserved = torch.cuda.max_memory_reserved() / (1024 ** 2)

    print(f"Allocated GPU Memory: {allocated:.2f} MB")
    print(f"Reserved GPU Memory: {reserved:.2f} MB")
    print(f"Max GPU Memory: {max_reserved:.2f} MB\n")

# Model Parameters
total_params = sum(
    p.numel() for p in model.parameters()
)

trainable_params = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print(f"Total Parameters: {total_params}")
print(f"Trainable Parameters: {trainable_params}\n")

# Graph Memory
node_memory = (
    graph.x.element_size()
    * graph.x.nelement()
) / (1024 ** 2)

edge_memory = (
    graph.edge_index.element_size()
    * graph.edge_index.nelement()
) / (1024 ** 2)

graph_memory = node_memory + edge_memory

print(f"Node Feature Memory: {node_memory:.2f} MB")
print(f"Edge Memory: {edge_memory:.2f} MB")
print(f"Total Graph Memory: {graph_memory:.2f} MB")

print("=" * 60)
# Out:
# ============================================================
# Training Time: 108.02 seconds (150 epochs)
#
# Allocated GPU Memory: 95.10 MB
# Reserved GPU Memory: 7846.00 MB
# Max GPU Memory: 7846.00 MB
#
# Total Parameters: 214146
# Trainable Parameters: 214146
#
# Node Feature Memory: 46.30 MB
# Edge Memory: 24.41 MB
# Total Graph Memory: 70.71 MB
# ============================================================
