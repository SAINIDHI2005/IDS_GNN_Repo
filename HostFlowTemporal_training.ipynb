# %% [markdown]
# <a href="https://colab.research.google.com/github/SAINIDHI2005/IDS_GNN_Repo/blob/main/HostFlowTemporal_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch-geometric -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 31.5 MB/s eta 0:00:00

# %%
import os

import pandas as pd
import numpy as np

import torch

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from torch_geometric.data import Data

# %%
DATASET_DIR = "/content/drive/MyDrive/CIC_IoT_2023/Host_flow_temporal"

files = {
    "BENIGN.csv":0,
    "DDoS.csv":1,
    "DoS.csv":1,
    "Mirai.csv":1,
    "Recon.csv":1,
    "Spoofing.csv":1
}

dfs = []

for file,label in files.items():

    path = os.path.join(DATASET_DIR,file)

    df = pd.read_csv(path)

    attack_name = file.replace(".csv","")

    df["attack_type"] = attack_name

    df["label"] = label

    dfs.append(df)

data = pd.concat(
    dfs,
    ignore_index=True
)

print(data.shape)

print(data["attack_type"].value_counts())
# Out:
# (400000, 88)
# attack_type
# BENIGN      200000
# DDoS         40000
# DoS          40000
# Mirai        40000
# Recon        40000
# Spoofing     40000
# Name: count, dtype: int64

# %%
data = data.sort_values(
    "bidirectional_first_seen_ms"
).reset_index(drop=True)

data["flow_id"] = np.arange(len(data))

print(data.shape)
# Out:
# (400000, 89)

# %%
attack_type_backup = data["attack_type"].copy()

# %%
DROP_COLS = [

    "id",
    "expiration_id",

    "src_ip",
    "dst_ip",

    "src_mac",
    "dst_mac",

    "src_oui",
    "dst_oui",

    "requested_server_name",

    "client_fingerprint",
    "server_fingerprint",

    "user_agent",
    "content_type",

    "application_name",
    "application_category_name",

    "flow_id",
    "label",
    "attack_type",

    "bidirectional_first_seen_ms",
    "bidirectional_last_seen_ms",

    "src2dst_first_seen_ms",
    "src2dst_last_seen_ms",

    "dst2src_first_seen_ms",
    "dst2src_last_seen_ms",

    "application_confidence",
    "application_is_guessed",

    "vlan_id",
    "tunnel_id",

    "bidirectional_urg_packets",
    "src2dst_urg_packets",
    "dst2src_urg_packets",

    "dst2src_cwr_packets",
    "dst2src_ece_packets",

    "src_port",

    "bidirectional_duration_ms",
    "bidirectional_packets",

    "src2dst_packets",
    "dst2src_packets",

    "dst2src_min_ps",
    "dst2src_mean_ps",

    "bidirectional_min_piat_ms",
    "bidirectional_stddev_piat_ms",

    "dst2src_min_piat_ms",
    "dst2src_mean_piat_ms",
    "dst2src_max_piat_ms",

    "bidirectional_ece_packets",
    "bidirectional_psh_packets",
    "bidirectional_fin_packets",

    "src2dst_syn_packets",
    "src2dst_cwr_packets",
    "src2dst_ack_packets",
    "src2dst_rst_packets",
    "src2dst_fin_packets",

    "src2dst_mean_piat_ms",
    "src2dst_stddev_ps",

    "dst2src_ack_packets",
    "dst2src_psh_packets",
    "dst2src_rst_packets",
    "dst2src_fin_packets",

]

feature_cols = [

    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:",len(feature_cols))
# Out:
# Features: 30

# %%
feature_cols = [
    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:", len(feature_cols))

print("\nRetained Features:\n")
for i, f in enumerate(feature_cols, start=1):
    print(f"{i:2d}. {f}")
# Out:
# Features: 30
#
# Retained Features:
#
#  1. dst_port
#  2. protocol
#  3. ip_version
#  4. bidirectional_bytes
#  5. src2dst_duration_ms
#  6. src2dst_bytes
#  7. dst2src_duration_ms
#  8. dst2src_bytes
#  9. bidirectional_min_ps
# 10. bidirectional_mean_ps
# 11. bidirectional_stddev_ps
# 12. bidirectional_max_ps
# 13. src2dst_min_ps
# 14. src2dst_mean_ps
# 15. src2dst_max_ps
# 16. dst2src_stddev_ps
# 17. dst2src_max_ps
# 18. bidirectional_mean_piat_ms
# 19. bidirectional_max_piat_ms
# 20. src2dst_min_piat_ms
# 21. src2dst_stddev_piat_ms
# 22. src2dst_max_piat_ms
# 23. dst2src_stddev_piat_ms
# 24. bidirectional_syn_packets
# 25. bidirectional_cwr_packets
# 26. bidirectional_ack_packets
# 27. bidirectional_rst_packets
# 28. src2dst_ece_packets
# 29. src2dst_psh_packets
# 30. dst2src_syn_packets

# %%
top30 = {
    "bidirectional_mean_ps",
    "dst2src_syn_packets",
    "src2dst_min_ps",
    "ip_version",
    "src2dst_max_piat_ms",
    "dst2src_stddev_piat_ms",
    "bidirectional_max_piat_ms",
    "bidirectional_rst_packets",
    "src2dst_max_ps",
    "src2dst_duration_ms",
    "src2dst_bytes",
    "src2dst_ece_packets",
    "bidirectional_max_ps",
    "dst2src_bytes",
    "bidirectional_bytes",
    "dst2src_max_ps",
    "bidirectional_min_ps",
    "bidirectional_syn_packets",
    "dst2src_stddev_ps",
    "bidirectional_ack_packets",
    "protocol",
    "dst_port",
    "bidirectional_mean_piat_ms",
    "dst2src_duration_ms",
    "src2dst_mean_ps",
    "src2dst_min_piat_ms",
    "bidirectional_stddev_ps",
    "src2dst_stddev_piat_ms",
    "bidirectional_cwr_packets",
    "src2dst_psh_packets"
}

retained = set(feature_cols)

print("Missing from retained:")
print(sorted(top30 - retained))

print("\nExtra retained features:")
print(sorted(retained - top30))
# Out:
# Missing from retained:
# []
#
# Extra retained features:
# []

# %%
for col in feature_cols:

    data[col] = pd.to_numeric(
        data[col],
        errors="coerce"
    )

data[feature_cols] = (
    data[feature_cols]
    .fillna(0)
)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(
    data[feature_cols]
)

print(X.shape)
# Out:
# (400000, 30)

# %%
all_hosts = pd.concat(
    [
        data["src_ip"],
        data["dst_ip"]
    ]
).unique()

host_to_id = {

    host : idx + len(data)

    for idx,host
    in enumerate(all_hosts)
}

num_flow_nodes = len(data)

num_host_nodes = len(all_hosts)

print("Flow Nodes:",num_flow_nodes)
print("Host Nodes:",num_host_nodes)
# Out:
# Flow Nodes: 400000
# Host Nodes: 4572

# %%
edges = []

for flow_id,row in data.iterrows():

    src_host = host_to_id[
        row["src_ip"]
    ]

    dst_host = host_to_id[
        row["dst_ip"]
    ]

    edges.append(
        [flow_id,src_host]
    )

    edges.append(
        [src_host,flow_id]
    )

    edges.append(
        [flow_id,dst_host]
    )

    edges.append(
        [dst_host,flow_id]
    )

print("Host-flow edges built")
# Out:
# Host-flow edges built

# %%
src_groups = data.groupby(
    "src_ip"
)["flow_id"].apply(list)

print(
    "Groups:",
    len(src_groups)
)
# Out:
# Groups: 1303

# %%
# ==================================
# TEMPORAL FLOW-FLOW EDGES
# ==================================

src_groups = data.groupby("src_ip")["flow_id"].apply(list)

temporal_edges = 0

for flow_list in src_groups:

    n = len(flow_list)

    if n < 2:
        continue

    for i in range(n):

        f1 = flow_list[i]

        for k in [1, 2, 3]:

            if i + k < n:

                f2 = flow_list[i + k]

                edges.append([f1, f2])
                edges.append([f2, f1])

                temporal_edges += 2

print("Temporal edges added:", temporal_edges)
print("Total edges:", len(edges))
# Out:
# Temporal edges added: 2388190
# Total edges: 3988190

# %%
edge_index = torch.tensor(
    edges,
    dtype=torch.long
).t().contiguous()

print(edge_index.shape)
# Out:
# torch.Size([2, 3988190])

# %%
flow_features = torch.tensor(
    X,
    dtype=torch.float
)

# %%
host_features = torch.zeros(

    (
        num_host_nodes,
        flow_features.shape[1]
    ),

    dtype=torch.float
)

host_counts = np.zeros(
    num_host_nodes
)

for flow_id,row in data.iterrows():

    src_idx = (
        host_to_id[
            row["src_ip"]
        ]
        -
        num_flow_nodes
    )

    dst_idx = (
        host_to_id[
            row["dst_ip"]
        ]
        -
        num_flow_nodes
    )

    host_features[src_idx] += flow_features[flow_id]
    host_features[dst_idx] += flow_features[flow_id]

    host_counts[src_idx] += 1
    host_counts[dst_idx] += 1

for i in range(num_host_nodes):

    if host_counts[i] > 0:

        host_features[i] /= (
            host_counts[i]
        )

# %%
x = torch.cat(
    [
        flow_features,
        host_features
    ],
    dim=0
)

print(x.shape)
# Out:
# torch.Size([404572, 30])

# %%
flow_labels = torch.tensor(
    data["label"].values,
    dtype=torch.long
)

host_labels = torch.full(
    (
        num_host_nodes,
    ),
    -1,
    dtype=torch.long
)

y = torch.cat(
    [
        flow_labels,
        host_labels
    ]
)

print(y.shape)
# Out:
# torch.Size([404572])

# %%
flow_hosts = (
    data["src_ip"].astype(str)
    + "_"
    + data["dst_ip"].astype(str)
)

unique_pairs = flow_hosts.unique()

train_pairs, val_pairs = train_test_split(
    unique_pairs,
    test_size=0.2,
    random_state=42
)

train_idx = data[
    flow_hosts.isin(train_pairs)
].index.values

val_idx = data[
    flow_hosts.isin(val_pairs)
].index.values

print("Train flows:", len(train_idx))
print("Validation flows:", len(val_idx))

print("Train pairs:", len(train_pairs))
print("Validation pairs:", len(val_pairs))
# Out:
# Train flows: 313475
# Validation flows: 86525
# Train pairs: 9756
# Validation pairs: 2439

# %%
total_nodes = (
    num_flow_nodes
    +
    num_host_nodes
)

train_mask = torch.zeros(total_nodes,dtype=torch.bool)

val_mask = torch.zeros(total_nodes,dtype=torch.bool)

train_mask[train_idx] = True
val_mask[val_idx] = True

print("Train mask:", train_mask.sum().item())
print("Validation mask :",val_mask.sum().item())
# Out:
# Train mask: 313475
# Validation mask : 86525

# %%
graph = Data(
    x=x,
    edge_index=edge_index,
    y=y,
    train_mask=train_mask,
    val_mask=val_mask
)
print(graph)

print(
    "Nodes:",
    graph.num_nodes
)

print(
    "Edges:",
    graph.num_edges
)
# Out:
# Data(x=[404572, 30], edge_index=[2, 3988190], y=[404572], train_mask=[404572], val_mask=[404572])
# Nodes: 404572
# Edges: 3988190

# %%
import torch
import torch.nn.functional as F

from torch_geometric.nn import SAGEConv

class GraphSAGE(torch.nn.Module):

    def __init__(
        self,
        in_channels,
        hidden_channels,
        num_classes
    ):

        super().__init__()

        self.conv1 = SAGEConv(
            in_channels,
            hidden_channels
        )

        self.conv2 = SAGEConv(
            hidden_channels,
            hidden_channels
        )

        self.conv3 = SAGEConv(
            hidden_channels,
            hidden_channels // 2
        )

        self.bn1 = torch.nn.BatchNorm1d(
            hidden_channels
        )

        self.bn2 = torch.nn.BatchNorm1d(
            hidden_channels
        )

        self.bn3 = torch.nn.BatchNorm1d(
            hidden_channels // 2
        )

        self.classifier = torch.nn.Linear(
            hidden_channels // 2,
            num_classes
        )

    def forward(
        self,
        x,
        edge_index
    ):

        x = self.conv1(
            x,
            edge_index
        )

        x = self.bn1(x)

        x = F.relu(x)

        x = F.dropout(
            x,
            p=0.4,
            training=self.training
        )

        x = self.conv2(
            x,
            edge_index
        )

        x = self.bn2(x)

        x = F.relu(x)

        x = F.dropout(
            x,
            p=0.4,
            training=self.training
        )

        x = self.conv3(
            x,
            edge_index
        )

        x = self.bn3(x)

        x = F.relu(x)

        x = self.classifier(x)

        return x

# %%
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print(device)
# Out:
# cuda

# %%
model = GraphSAGE(
    in_channels=graph.num_node_features,
    hidden_channels=256,
    num_classes=2
)

model = model.to(device)

graph = graph.to(device)

print(model)
# Out:
# GraphSAGE(
#   (conv1): SAGEConv(30, 256, aggr=mean)
#   (conv2): SAGEConv(256, 256, aggr=mean)
#   (conv3): SAGEConv(256, 128, aggr=mean)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.002,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=20,
    gamma=0.5
)

# %%
weights = torch.tensor(
    [1.0, 1.5],
    dtype=torch.float
).to(device)

criterion = torch.nn.CrossEntropyLoss(
    weight=weights
)

# %%
def train():

    model.train()

    optimizer.zero_grad()

    out = model(
        graph.x,
        graph.edge_index
    )

    loss = criterion(
        out[graph.train_mask],
        graph.y[graph.train_mask]
    )

    loss.backward()

    optimizer.step()

    return loss.item()

# %%
@torch.no_grad()

def evaluate(mask):

    model.eval()

    out = model(
        graph.x,
        graph.edge_index
    )

    pred = out.argmax(
        dim=1
    )

    correct = (
        pred[mask]
        ==
        graph.y[mask]
    ).sum()

    acc = (
        correct.item()
        /
        mask.sum().item()
    )

    return acc

# %%
import time

start_time = time.time()

# %%
import os
import joblib
import torch

best_val_acc = 0
best_epoch = 0

SAVE_DIR = r"/content/drive/MyDrive/CIC_IoT_2023/Saved_Model"
os.makedirs(SAVE_DIR, exist_ok=True)

for epoch in range(1, 91):

    loss = train()

    train_acc = evaluate(graph.train_mask)
    val_acc = evaluate(graph.val_mask)

    if val_acc > best_val_acc:

        best_val_acc = val_acc
        best_epoch = epoch



    scheduler.step()

    print(
        f"Epoch {epoch:02d}"
        f" | Loss {loss:.4f}"
        f" | Train {train_acc:.4f}"
        f" | Validation {val_acc:.4f}"
    )


end_time = time.time()

training_time = end_time - start_time

print(f"Training Time: {training_time:.2f} seconds ({epoch} epochs)")
print(f"Best Epoch: {best_epoch}")
print(f"Best Validation Accuracy: {best_val_acc:.4f}")
print("Training Complete.")
# Out:
# Epoch 01 | Loss 0.1121 | Train 0.9682 | Validation 0.9411
# Epoch 02 | Loss 0.1173 | Train 0.9681 | Validation 0.9408
# Epoch 03 | Loss 0.1122 | Train 0.9682 | Validation 0.9410
# Epoch 04 | Loss 0.1136 | Train 0.9682 | Validation 0.9410
# Epoch 05 | Loss 0.1131 | Train 0.9682 | Validation 0.9410
# Epoch 06 | Loss 0.1115 | Train 0.9681 | Validation 0.9410
# Epoch 07 | Loss 0.1127 | Train 0.9682 | Validation 0.9410
# Epoch 08 | Loss 0.1101 | Train 0.9683 | Validation 0.9414
# Epoch 09 | Loss 0.1126 | Train 0.9683 | Validation 0.9412
# Epoch 10 | Loss 0.1156 | Train 0.9682 | Validation 0.9411
# Epoch 11 | Loss 0.1130 | Train 0.9683 | Validation 0.9413
# Epoch 12 | Loss 0.1072 | Train 0.9683 | Validation 0.9415
# Epoch 13 | Loss 0.1125 | Train 0.9683 | Validation 0.9416
# Epoch 14 | Loss 0.1187 | Train 0.9683 | Validation 0.9417
# Epoch 15 | Loss 0.1096 | Train 0.9683 | Validation 0.9413
# Epoch 16 | Loss 0.1140 | Train 0.9688 | Validation 0.9410
# Epoch 17 | Loss 0.1143 | Train 0.9691 | Validation 0.9410
# Epoch 18 | Loss 0.1139 | Train 0.9691 | Validation 0.9408
# Epoch 19 | Loss 0.1135 | Train 0.9691 | Validation 0.9410
# Epoch 20 | Loss 0.1121 | Train 0.9692 | Validation 0.9410
# Epoch 21 | Loss 0.1103 | Train 0.9691 | Validation 0.9410
# Epoch 22 | Loss 0.1100 | Train 0.9686 | Validation 0.9411
# Epoch 23 | Loss 0.1075 | Train 0.9686 | Validation 0.9411
# Epoch 24 | Loss 0.1138 | Train 0.9689 | Validation 0.9411
# Epoch 25 | Loss 0.1138 | Train 0.9691 | Validation 0.9410
# Epoch 26 | Loss 0.1088 | Train 0.9691 | Validation 0.9410
# Epoch 27 | Loss 0.1147 | Train 0.9690 | Validation 0.9407
# Epoch 28 | Loss 0.1112 | Train 0.9691 | Validation 0.9411
# Epoch 29 | Loss 0.1128 | Train 0.9691 | Validation 0.9411
# Epoch 30 | Loss 0.1072 | Train 0.9691 | Validation 0.9411
# Epoch 31 | Loss 0.1149 | Train 0.9684 | Validation 0.9411
# Epoch 32 | Loss 0.1117 | Train 0.9685 | Validation 0.9411
# Epoch 33 | Loss 0.1142 | Train 0.9691 | Validation 0.9408
# Epoch 34 | Loss 0.1163 | Train 0.9692 | Validation 0.9410
# Epoch 35 | Loss 0.1138 | Train 0.9686 | Validation 0.9410
# Epoch 36 | Loss 0.1123 | Train 0.9690 | Validation 0.9410
# Epoch 37 | Loss 0.1126 | Train 0.9684 | Validation 0.9410
# Epoch 38 | Loss 0.1153 | Train 0.9690 | Validation 0.9410
# Epoch 39 | Loss 0.1160 | Train 0.9691 | Validation 0.9405
# Epoch 40 | Loss 0.1136 | Train 0.9691 | Validation 0.9406
# Epoch 41 | Loss 0.1110 | Train 0.9691 | Validation 0.9406
# Epoch 42 | Loss 0.1149 | Train 0.9690 | Validation 0.9402
# Epoch 43 | Loss 0.1092 | Train 0.9691 | Validation 0.9405
# Epoch 44 | Loss 0.1124 | Train 0.9691 | Validation 0.9403
# Epoch 45 | Loss 0.1110 | Train 0.9691 | Validation 0.9406
# Epoch 46 | Loss 0.1133 | Train 0.9691 | Validation 0.9406
# Epoch 47 | Loss 0.1143 | Train 0.9686 | Validation 0.9409
# Epoch 48 | Loss 0.1140 | Train 0.9683 | Validation 0.9411
# Epoch 49 | Loss 0.1094 | Train 0.9683 | Validation 0.9411
# Epoch 50 | Loss 0.1102 | Train 0.9683 | Validation 0.9411
# Epoch 51 | Loss 0.1107 | Train 0.9683 | Validation 0.9411
# Epoch 52 | Loss 0.1123 | Train 0.9683 | Validation 0.9409
# Epoch 53 | Loss 0.1117 | Train 0.9683 | Validation 0.9412
# Epoch 54 | Loss 0.1180 | Train 0.9683 | Validation 0.9411
# Epoch 55 | Loss 0.1120 | Train 0.9683 | Validation 0.9413
# Epoch 56 | Loss 0.1154 | Train 0.9683 | Validation 0.9412
# Epoch 57 | Loss 0.1084 | Train 0.9685 | Validation 0.9410
# Epoch 58 | Loss 0.1129 | Train 0.9684 | Validation 0.9411
# Epoch 59 | Loss 0.1148 | Train 0.9689 | Validation 0.9409
# Epoch 60 | Loss 0.1201 | Train 0.9691 | Validation 0.9404
# Epoch 61 | Loss 0.1155 | Train 0.9691 | Validation 0.9403
# Epoch 62 | Loss 0.1124 | Train 0.9690 | Validation 0.9401
# Epoch 63 | Loss 0.1122 | Train 0.9690 | Validation 0.9400
# Epoch 64 | Loss 0.1134 | Train 0.9690 | Validation 0.9400
# Epoch 65 | Loss 0.1138 | Train 0.9690 | Validation 0.9401
# Epoch 66 | Loss 0.1140 | Train 0.9689 | Validation 0.9399
# Epoch 67 | Loss 0.1089 | Train 0.9690 | Validation 0.9400
# Epoch 68 | Loss 0.1095 | Train 0.9691 | Validation 0.9406
# Epoch 69 | Loss 0.1116 | Train 0.9691 | Validation 0.9406
# Epoch 70 | Loss 0.1134 | Train 0.9692 | Validation 0.9406
# Epoch 71 | Loss 0.1140 | Train 0.9692 | Validation 0.9407
# Epoch 72 | Loss 0.1138 | Train 0.9692 | Validation 0.9409
# Epoch 73 | Loss 0.1126 | Train 0.9692 | Validation 0.9406
# Epoch 74 | Loss 0.1108 | Train 0.9692 | Validation 0.9410
# Epoch 75 | Loss 0.1137 | Train 0.9691 | Validation 0.9407
# Epoch 76 | Loss 0.1134 | Train 0.9691 | Validation 0.9409
# Epoch 77 | Loss 0.1134 | Train 0.9690 | Validation 0.9410
# Epoch 78 | Loss 0.1109 | Train 0.9686 | Validation 0.9411
# Epoch 79 | Loss 0.1157 | Train 0.9691 | Validation 0.9410
# Epoch 80 | Loss 0.1117 | Train 0.9692 | Validation 0.9409
# Epoch 81 | Loss 0.1142 | Train 0.9691 | Validation 0.9407
# Epoch 82 | Loss 0.1123 | Train 0.9692 | Validation 0.9408
# Epoch 83 | Loss 0.1127 | Train 0.9691 | Validation 0.9401
# Epoch 84 | Loss 0.1130 | Train 0.9690 | Validation 0.9402
# Epoch 85 | Loss 0.1196 | Train 0.9688 | Validation 0.9396
# Epoch 86 | Loss 0.1106 | Train 0.9688 | Validation 0.9396
# Epoch 87 | Loss 0.1178 | Train 0.9688 | Validation 0.9396
# Epoch 88 | Loss 0.1140 | Train 0.9688 | Validation 0.9396
# Epoch 89 | Loss 0.1129 | Train 0.9688 | Validation 0.9396
# Epoch 90 | Loss 0.1129 | Train 0.9688 | Validation 0.9396
# Training Time: 374.52 seconds (90 epochs)
# Best Epoch: 14
# Best Validation Accuracy: 0.9417
# Training Complete.
