# %% [markdown]
# <a href="https://colab.research.google.com/github/SAINIDHI2005/IDS_GNN_Repo/blob/main/graphSAGE/HostFlowTemporal_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch-geometric -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.8 MB/s eta 0:00:00

# %%
import os

import pandas as pd
import numpy as np

import torch

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from torch_geometric.data import Data

# %%
DATASET_DIR = "/content/drive/MyDrive/CIC_IoT_2023/Host_flow_temporal"

files = {
    "BENIGN.csv":0,
    "DDoS.csv":1,
    "DoS.csv":1,
    "Mirai.csv":1,
    "Recon.csv":1,
    "Spoofing.csv":1
}

dfs = []

for file,label in files.items():

    path = os.path.join(DATASET_DIR,file)

    df = pd.read_csv(path)

    attack_name = file.replace(".csv","")

    df["attack_type"] = attack_name

    df["label"] = label

    dfs.append(df)

data = pd.concat(
    dfs,
    ignore_index=True
)

print(data.shape)

print(data["attack_type"].value_counts())
# Out:
# (400000, 88)
# attack_type
# BENIGN      200000
# DDoS         40000
# DoS          40000
# Mirai        40000
# Recon        40000
# Spoofing     40000
# Name: count, dtype: int64

# %%
data = data.sort_values(
    "bidirectional_first_seen_ms"
).reset_index(drop=True)

data["flow_id"] = np.arange(len(data))

print(data.shape)
# Out:
# (400000, 89)

# %%
attack_type_backup = data["attack_type"].copy()

# %%
DROP_COLS = [

    "id",
    "expiration_id",

    "src_ip",
    "dst_ip",

    "src_mac",
    "dst_mac",

    "src_oui",
    "dst_oui",

    "requested_server_name",

    "client_fingerprint",
    "server_fingerprint",

    "user_agent",
    "content_type",

    "application_name",
    "application_category_name",

    "flow_id",
    "label",
    "attack_type",

    "bidirectional_first_seen_ms",
    "bidirectional_last_seen_ms",

    "src2dst_first_seen_ms",
    "src2dst_last_seen_ms",

    "dst2src_first_seen_ms",
    "dst2src_last_seen_ms",

    "application_confidence",
    "application_is_guessed",

    "vlan_id",
    "tunnel_id",

    "bidirectional_urg_packets",
    "src2dst_urg_packets",
    "dst2src_urg_packets",

    "dst2src_cwr_packets",
    "dst2src_ece_packets",

    "src_port",

    "bidirectional_duration_ms",
    "bidirectional_packets",

    "src2dst_packets",
    "dst2src_packets",

    "dst2src_min_ps",
    "dst2src_mean_ps",

    "bidirectional_min_piat_ms",
    "bidirectional_stddev_piat_ms",

    "dst2src_min_piat_ms",
    "dst2src_mean_piat_ms",
    "dst2src_max_piat_ms",

    "bidirectional_ece_packets",
    "bidirectional_psh_packets",
    "bidirectional_fin_packets",

    "src2dst_syn_packets",
    "src2dst_cwr_packets",
    "src2dst_ack_packets",
    "src2dst_rst_packets",
    "src2dst_fin_packets",

    "src2dst_mean_piat_ms",
    "src2dst_stddev_ps",

    "dst2src_ack_packets",
    "dst2src_psh_packets",
    "dst2src_rst_packets",
    "dst2src_fin_packets",

]

feature_cols = [

    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:",len(feature_cols))
# Out:
# Features: 30

# %%
feature_cols = [
    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:", len(feature_cols))

print("\nRetained Features:\n")
for i, f in enumerate(feature_cols, start=1):
    print(f"{i:2d}. {f}")
# Out:
# Features: 30
#
# Retained Features:
#
#  1. dst_port
#  2. protocol
#  3. ip_version
#  4. bidirectional_bytes
#  5. src2dst_duration_ms
#  6. src2dst_bytes
#  7. dst2src_duration_ms
#  8. dst2src_bytes
#  9. bidirectional_min_ps
# 10. bidirectional_mean_ps
# 11. bidirectional_stddev_ps
# 12. bidirectional_max_ps
# 13. src2dst_min_ps
# 14. src2dst_mean_ps
# 15. src2dst_max_ps
# 16. dst2src_stddev_ps
# 17. dst2src_max_ps
# 18. bidirectional_mean_piat_ms
# 19. bidirectional_max_piat_ms
# 20. src2dst_min_piat_ms
# 21. src2dst_stddev_piat_ms
# 22. src2dst_max_piat_ms
# 23. dst2src_stddev_piat_ms
# 24. bidirectional_syn_packets
# 25. bidirectional_cwr_packets
# 26. bidirectional_ack_packets
# 27. bidirectional_rst_packets
# 28. src2dst_ece_packets
# 29. src2dst_psh_packets
# 30. dst2src_syn_packets

# %%
top30 = {
    "bidirectional_mean_ps",
    "dst2src_syn_packets",
    "src2dst_min_ps",
    "ip_version",
    "src2dst_max_piat_ms",
    "dst2src_stddev_piat_ms",
    "bidirectional_max_piat_ms",
    "bidirectional_rst_packets",
    "src2dst_max_ps",
    "src2dst_duration_ms",
    "src2dst_bytes",
    "src2dst_ece_packets",
    "bidirectional_max_ps",
    "dst2src_bytes",
    "bidirectional_bytes",
    "dst2src_max_ps",
    "bidirectional_min_ps",
    "bidirectional_syn_packets",
    "dst2src_stddev_ps",
    "bidirectional_ack_packets",
    "protocol",
    "dst_port",
    "bidirectional_mean_piat_ms",
    "dst2src_duration_ms",
    "src2dst_mean_ps",
    "src2dst_min_piat_ms",
    "bidirectional_stddev_ps",
    "src2dst_stddev_piat_ms",
    "bidirectional_cwr_packets",
    "src2dst_psh_packets"
}

retained = set(feature_cols)

print("Missing from retained:")
print(sorted(top30 - retained))

print("\nExtra retained features:")
print(sorted(retained - top30))
# Out:
# Missing from retained:
# []
#
# Extra retained features:
# []

# %%
for col in feature_cols:

    data[col] = pd.to_numeric(
        data[col],
        errors="coerce"
    )

data[feature_cols] = (
    data[feature_cols]
    .fillna(0)
)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(
    data[feature_cols]
)

print(X.shape)
# Out:
# (400000, 30)

# %%
all_hosts = pd.concat(
    [
        data["src_ip"],
        data["dst_ip"]
    ]
).unique()

host_to_id = {

    host : idx + len(data)

    for idx,host
    in enumerate(all_hosts)
}

num_flow_nodes = len(data)

num_host_nodes = len(all_hosts)

print("Flow Nodes:",num_flow_nodes)
print("Host Nodes:",num_host_nodes)
# Out:
# Flow Nodes: 400000
# Host Nodes: 4572

# %%
edges = []

for flow_id,row in data.iterrows():

    src_host = host_to_id[
        row["src_ip"]
    ]

    dst_host = host_to_id[
        row["dst_ip"]
    ]

    edges.append(
        [flow_id,src_host]
    )

    edges.append(
        [src_host,flow_id]
    )

    edges.append(
        [flow_id,dst_host]
    )

    edges.append(
        [dst_host,flow_id]
    )

print("Host-flow edges built")
# Out:
# Host-flow edges built

# %%
src_groups = data.groupby(
    "src_ip"
)["flow_id"].apply(list)

print(
    "Groups:",
    len(src_groups)
)
# Out:
# Groups: 1303

# %%
# ==================================
# TEMPORAL FLOW-FLOW EDGES
# ==================================

src_groups = data.groupby("src_ip")["flow_id"].apply(list)

temporal_edges = 0

for flow_list in src_groups:

    n = len(flow_list)

    if n < 2:
        continue

    for i in range(n):

        f1 = flow_list[i]

        for k in [1, 2, 3]:

            if i + k < n:

                f2 = flow_list[i + k]

                edges.append([f1, f2])
                edges.append([f2, f1])

                temporal_edges += 2

print("Temporal edges added:", temporal_edges)
print("Total edges:", len(edges))
# Out:
# Temporal edges added: 2388190
# Total edges: 3988190

# %%
edge_index = torch.tensor(
    edges,
    dtype=torch.long
).t().contiguous()

print(edge_index.shape)
# Out:
# torch.Size([2, 3988190])

# %%
flow_features = torch.tensor(
    X,
    dtype=torch.float
)

# %%
host_features = torch.zeros(

    (
        num_host_nodes,
        flow_features.shape[1]
    ),

    dtype=torch.float
)

host_counts = np.zeros(
    num_host_nodes
)

for flow_id,row in data.iterrows():

    src_idx = (
        host_to_id[
            row["src_ip"]
        ]
        -
        num_flow_nodes
    )

    dst_idx = (
        host_to_id[
            row["dst_ip"]
        ]
        -
        num_flow_nodes
    )

    host_features[src_idx] += flow_features[flow_id]
    host_features[dst_idx] += flow_features[flow_id]

    host_counts[src_idx] += 1
    host_counts[dst_idx] += 1

for i in range(num_host_nodes):

    if host_counts[i] > 0:

        host_features[i] /= (
            host_counts[i]
        )

# %%
x = torch.cat(
    [
        flow_features,
        host_features
    ],
    dim=0
)

print(x.shape)
# Out:
# torch.Size([404572, 30])

# %%
flow_labels = torch.tensor(
    data["label"].values,
    dtype=torch.long
)

host_labels = torch.full(
    (
        num_host_nodes,
    ),
    -1,
    dtype=torch.long
)

y = torch.cat(
    [
        flow_labels,
        host_labels
    ]
)

print(y.shape)
# Out:
# torch.Size([404572])

# %%
flow_hosts = (
    data["src_ip"].astype(str)
    + "_"
    + data["dst_ip"].astype(str)
)

unique_pairs = flow_hosts.unique()

train_pairs, val_pairs = train_test_split(
    unique_pairs,
    test_size=0.2,
    random_state=42
)

train_idx = data[
    flow_hosts.isin(train_pairs)
].index.values

val_idx = data[
    flow_hosts.isin(val_pairs)
].index.values

print("Train flows:", len(train_idx))
print("Validation flows:", len(val_idx))

print("Train pairs:", len(train_pairs))
print("Validation pairs:", len(val_pairs))
# Out:
# Train flows: 313475
# Validation flows: 86525
# Train pairs: 9756
# Validation pairs: 2439

# %%
total_nodes = (
    num_flow_nodes
    +
    num_host_nodes
)

train_mask = torch.zeros(total_nodes,dtype=torch.bool)

val_mask = torch.zeros(total_nodes,dtype=torch.bool)

train_mask[train_idx] = True
val_mask[val_idx] = True

print("Train mask:", train_mask.sum().item())
print("Validation mask :",val_mask.sum().item())
# Out:
# Train mask: 313475
# Validation mask : 86525

# %%
graph = Data(
    x=x,
    edge_index=edge_index,
    y=y,
    train_mask=train_mask,
    val_mask=val_mask
)
print(graph)

print(
    "Nodes:",
    graph.num_nodes
)

print(
    "Edges:",
    graph.num_edges
)
# Out:
# Data(x=[404572, 30], edge_index=[2, 3988190], y=[404572], train_mask=[404572], val_mask=[404572])
# Nodes: 404572
# Edges: 3988190

# %%
import torch
import torch.nn.functional as F

from torch_geometric.nn import SAGEConv

class GraphSAGE(torch.nn.Module):

    def __init__(
        self,
        in_channels,
        hidden_channels,
        num_classes
    ):

        super().__init__()

        self.conv1 = SAGEConv(
            in_channels,
            hidden_channels
        )

        self.conv2 = SAGEConv(
            hidden_channels,
            hidden_channels
        )

        self.conv3 = SAGEConv(
            hidden_channels,
            hidden_channels // 2
        )

        self.bn1 = torch.nn.BatchNorm1d(
            hidden_channels
        )

        self.bn2 = torch.nn.BatchNorm1d(
            hidden_channels
        )

        self.bn3 = torch.nn.BatchNorm1d(
            hidden_channels // 2
        )

        self.classifier = torch.nn.Linear(
            hidden_channels // 2,
            num_classes
        )

    def forward(
        self,
        x,
        edge_index
    ):

        x = self.conv1(
            x,
            edge_index
        )

        x = self.bn1(x)

        x = F.relu(x)

        x = F.dropout(
            x,
            p=0.4,
            training=self.training
        )

        x = self.conv2(
            x,
            edge_index
        )

        x = self.bn2(x)

        x = F.relu(x)

        x = F.dropout(
            x,
            p=0.4,
            training=self.training
        )

        x = self.conv3(
            x,
            edge_index
        )

        x = self.bn3(x)

        x = F.relu(x)

        x = self.classifier(x)

        return x

# %%
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print(device)
# Out:
# cuda

# %%
model = GraphSAGE(
    in_channels=graph.num_node_features,
    hidden_channels=256,
    num_classes=2
)

model = model.to(device)

graph = graph.to(device)

print(model)
# Out:
# GraphSAGE(
#   (conv1): SAGEConv(30, 256, aggr=mean)
#   (conv2): SAGEConv(256, 256, aggr=mean)
#   (conv3): SAGEConv(256, 128, aggr=mean)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.002,
    weight_decay=1e-4
)

scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=20,
    gamma=0.5
)

# %%
weights = torch.tensor(
    [1.0, 1.5],
    dtype=torch.float
).to(device)

criterion = torch.nn.CrossEntropyLoss(
    weight=weights
)

# %%
def train():

    model.train()

    optimizer.zero_grad()

    out = model(
        graph.x,
        graph.edge_index
    )

    loss = criterion(
        out[graph.train_mask],
        graph.y[graph.train_mask]
    )

    loss.backward()

    optimizer.step()

    return loss.item()

# %%
@torch.no_grad()

def evaluate(mask):

    model.eval()

    out = model(
        graph.x,
        graph.edge_index
    )

    pred = out.argmax(
        dim=1
    )

    correct = (
        pred[mask]
        ==
        graph.y[mask]
    ).sum()

    acc = (
        correct.item()
        /
        mask.sum().item()
    )

    return acc

# %%
import os
import time
import joblib
import torch

best_val_acc = 0.0
best_epoch = 0

SAVE_DIR = r"/content/drive/MyDrive/CIC_IoT_2023/Saved_Model"
os.makedirs(SAVE_DIR, exist_ok=True)

start_time = time.time()

for epoch in range(1, 151):

    loss = train()

    train_acc = evaluate(graph.train_mask)
    val_acc = evaluate(graph.val_mask)

    # Save best model based on validation accuracy
    if val_acc > best_val_acc:

        best_val_acc = val_acc
        best_epoch = epoch

        torch.save(
            model.state_dict(),
            os.path.join(
                SAVE_DIR,
                "HostFlowTemporal_graphSAGE.pth"
            )
        )

        joblib.dump(
            scaler,
            os.path.join(
                SAVE_DIR,
                "HostFlowTemporal _scaler.pkl"
            )
        )

    scheduler.step()

    print(
        f"Epoch {epoch:03d}"
        f" | Loss {loss:.4f}"
        f" | Train {train_acc:.4f}"
        f" | Validation {val_acc:.4f}"
    )

end_time = time.time()

training_time = end_time - start_time

print("\n" + "=" * 60)
print(f"Training Time          : {training_time:.2f} seconds")
print(f"Best Epoch             : {best_epoch}")
print(f"Best Validation Acc.   : {best_val_acc:.4f}")
print(f"Model Saved At         : {os.path.join(SAVE_DIR,'HostFlow_graphSAGE.pth')}")
print(f"Scaler Saved At        : {os.path.join(SAVE_DIR,'HostFlow_scaler.pkl')}")
print("=" * 60)
print("Training Complete.")
# Out:
# Epoch 001 | Loss 0.6531 | Train 0.7926 | Validation 0.8056
# Epoch 002 | Loss 0.5232 | Train 0.7716 | Validation 0.7874
# Epoch 003 | Loss 0.4704 | Train 0.8141 | Validation 0.8105
# Epoch 004 | Loss 0.4097 | Train 0.8221 | Validation 0.8068
# Epoch 005 | Loss 0.3837 | Train 0.8166 | Validation 0.7970
# Epoch 006 | Loss 0.3611 | Train 0.8122 | Validation 0.8069
# Epoch 007 | Loss 0.3402 | Train 0.8157 | Validation 0.8098
# Epoch 008 | Loss 0.3270 | Train 0.8294 | Validation 0.8197
# Epoch 009 | Loss 0.3096 | Train 0.8469 | Validation 0.8255
# Epoch 010 | Loss 0.2935 | Train 0.8639 | Validation 0.8343
# Epoch 011 | Loss 0.2839 | Train 0.8744 | Validation 0.8462
# Epoch 012 | Loss 0.2748 | Train 0.8867 | Validation 0.8576
# Epoch 013 | Loss 0.2653 | Train 0.8872 | Validation 0.8579
# Epoch 014 | Loss 0.2578 | Train 0.8851 | Validation 0.8516
# Epoch 015 | Loss 0.2466 | Train 0.8889 | Validation 0.8527
# Epoch 016 | Loss 0.2441 | Train 0.8950 | Validation 0.8572
# Epoch 017 | Loss 0.2378 | Train 0.8974 | Validation 0.8578
# Epoch 018 | Loss 0.2318 | Train 0.8990 | Validation 0.8550
# Epoch 019 | Loss 0.2231 | Train 0.9002 | Validation 0.8538
# Epoch 020 | Loss 0.2182 | Train 0.9032 | Validation 0.8555
# Epoch 021 | Loss 0.2109 | Train 0.9074 | Validation 0.8591
# Epoch 022 | Loss 0.2041 | Train 0.9109 | Validation 0.8601
# Epoch 023 | Loss 0.2070 | Train 0.9137 | Validation 0.8588
# Epoch 024 | Loss 0.2036 | Train 0.9148 | Validation 0.8591
# Epoch 025 | Loss 0.1965 | Train 0.9156 | Validation 0.8593
# Epoch 026 | Loss 0.1949 | Train 0.9169 | Validation 0.8599
# Epoch 027 | Loss 0.1886 | Train 0.9190 | Validation 0.8618
# Epoch 028 | Loss 0.1846 | Train 0.9213 | Validation 0.8639
# Epoch 029 | Loss 0.1817 | Train 0.9235 | Validation 0.8669
# Epoch 030 | Loss 0.1784 | Train 0.9254 | Validation 0.8697
# Epoch 031 | Loss 0.1785 | Train 0.9279 | Validation 0.8810
# Epoch 032 | Loss 0.1745 | Train 0.9293 | Validation 0.8866
# Epoch 033 | Loss 0.1729 | Train 0.9303 | Validation 0.8873
# Epoch 034 | Loss 0.1640 | Train 0.9326 | Validation 0.8899
# Epoch 035 | Loss 0.1606 | Train 0.9351 | Validation 0.8916
# Epoch 036 | Loss 0.1558 | Train 0.9386 | Validation 0.8986
# Epoch 037 | Loss 0.1600 | Train 0.9426 | Validation 0.9057
# Epoch 038 | Loss 0.1561 | Train 0.9458 | Validation 0.9101
# Epoch 039 | Loss 0.1544 | Train 0.9470 | Validation 0.9103
# Epoch 040 | Loss 0.1466 | Train 0.9487 | Validation 0.9134
# Epoch 041 | Loss 0.1500 | Train 0.9500 | Validation 0.9155
# Epoch 042 | Loss 0.1519 | Train 0.9508 | Validation 0.9164
# Epoch 043 | Loss 0.1439 | Train 0.9520 | Validation 0.9185
# Epoch 044 | Loss 0.1461 | Train 0.9526 | Validation 0.9198
# Epoch 045 | Loss 0.1418 | Train 0.9533 | Validation 0.9212
# Epoch 046 | Loss 0.1414 | Train 0.9536 | Validation 0.9205
# Epoch 047 | Loss 0.1388 | Train 0.9543 | Validation 0.9216
# Epoch 048 | Loss 0.1440 | Train 0.9552 | Validation 0.9228
# Epoch 049 | Loss 0.1394 | Train 0.9567 | Validation 0.9257
# Epoch 050 | Loss 0.1438 | Train 0.9563 | Validation 0.9248
# Epoch 051 | Loss 0.1367 | Train 0.9570 | Validation 0.9261
# Epoch 052 | Loss 0.1359 | Train 0.9570 | Validation 0.9254
# Epoch 053 | Loss 0.1334 | Train 0.9572 | Validation 0.9268
# Epoch 054 | Loss 0.1353 | Train 0.9582 | Validation 0.9285
# Epoch 055 | Loss 0.1347 | Train 0.9590 | Validation 0.9309
# Epoch 056 | Loss 0.1288 | Train 0.9595 | Validation 0.9316
# Epoch 057 | Loss 0.1290 | Train 0.9595 | Validation 0.9321
# Epoch 058 | Loss 0.1342 | Train 0.9601 | Validation 0.9338
# Epoch 059 | Loss 0.1316 | Train 0.9609 | Validation 0.9352
# Epoch 060 | Loss 0.1278 | Train 0.9620 | Validation 0.9368
# Epoch 061 | Loss 0.1258 | Train 0.9623 | Validation 0.9372
# Epoch 062 | Loss 0.1266 | Train 0.9627 | Validation 0.9380
# Epoch 063 | Loss 0.1235 | Train 0.9630 | Validation 0.9384
# Epoch 064 | Loss 0.1226 | Train 0.9634 | Validation 0.9384
# Epoch 065 | Loss 0.1256 | Train 0.9631 | Validation 0.9381
# Epoch 066 | Loss 0.1230 | Train 0.9627 | Validation 0.9382
# Epoch 067 | Loss 0.1208 | Train 0.9624 | Validation 0.9390
# Epoch 068 | Loss 0.1226 | Train 0.9631 | Validation 0.9395
# Epoch 069 | Loss 0.1210 | Train 0.9644 | Validation 0.9412
# Epoch 070 | Loss 0.1236 | Train 0.9649 | Validation 0.9415
# Epoch 071 | Loss 0.1228 | Train 0.9648 | Validation 0.9412
# Epoch 072 | Loss 0.1204 | Train 0.9647 | Validation 0.9415
# Epoch 073 | Loss 0.1208 | Train 0.9646 | Validation 0.9419
# Epoch 074 | Loss 0.1211 | Train 0.9642 | Validation 0.9401
# Epoch 075 | Loss 0.1219 | Train 0.9642 | Validation 0.9398
# Epoch 076 | Loss 0.1239 | Train 0.9643 | Validation 0.9395
# Epoch 077 | Loss 0.1168 | Train 0.9642 | Validation 0.9398
# Epoch 078 | Loss 0.1177 | Train 0.9644 | Validation 0.9399
# Epoch 079 | Loss 0.1208 | Train 0.9647 | Validation 0.9411
# Epoch 080 | Loss 0.1153 | Train 0.9654 | Validation 0.9432
# Epoch 081 | Loss 0.1180 | Train 0.9661 | Validation 0.9439
# Epoch 082 | Loss 0.1161 | Train 0.9666 | Validation 0.9450
# Epoch 083 | Loss 0.1110 | Train 0.9668 | Validation 0.9457
# Epoch 084 | Loss 0.1131 | Train 0.9670 | Validation 0.9464
# Epoch 085 | Loss 0.1137 | Train 0.9674 | Validation 0.9470
# Epoch 086 | Loss 0.1147 | Train 0.9675 | Validation 0.9475
# Epoch 087 | Loss 0.1172 | Train 0.9675 | Validation 0.9474
# Epoch 088 | Loss 0.1139 | Train 0.9672 | Validation 0.9465
# Epoch 089 | Loss 0.1135 | Train 0.9667 | Validation 0.9460
# Epoch 090 | Loss 0.1079 | Train 0.9665 | Validation 0.9446
# Epoch 091 | Loss 0.1104 | Train 0.9662 | Validation 0.9438
# Epoch 092 | Loss 0.1152 | Train 0.9664 | Validation 0.9434
# Epoch 093 | Loss 0.1154 | Train 0.9665 | Validation 0.9438
# Epoch 094 | Loss 0.1120 | Train 0.9667 | Validation 0.9439
# Epoch 095 | Loss 0.1142 | Train 0.9669 | Validation 0.9442
# Epoch 096 | Loss 0.1109 | Train 0.9671 | Validation 0.9447
# Epoch 097 | Loss 0.1134 | Train 0.9673 | Validation 0.9451
# Epoch 098 | Loss 0.1080 | Train 0.9675 | Validation 0.9461
# Epoch 099 | Loss 0.1156 | Train 0.9675 | Validation 0.9454
# Epoch 100 | Loss 0.1099 | Train 0.9674 | Validation 0.9452
# Epoch 101 | Loss 0.1075 | Train 0.9674 | Validation 0.9453
# Epoch 102 | Loss 0.1100 | Train 0.9676 | Validation 0.9457
# Epoch 103 | Loss 0.1070 | Train 0.9676 | Validation 0.9458
# Epoch 104 | Loss 0.1145 | Train 0.9676 | Validation 0.9459
# Epoch 105 | Loss 0.1111 | Train 0.9677 | Validation 0.9461
# Epoch 106 | Loss 0.1199 | Train 0.9678 | Validation 0.9454
# Epoch 107 | Loss 0.1094 | Train 0.9677 | Validation 0.9452
# Epoch 108 | Loss 0.1113 | Train 0.9678 | Validation 0.9451
# Epoch 109 | Loss 0.1150 | Train 0.9678 | Validation 0.9454
# Epoch 110 | Loss 0.1146 | Train 0.9679 | Validation 0.9450
# Epoch 111 | Loss 0.1111 | Train 0.9680 | Validation 0.9450
# Epoch 112 | Loss 0.1129 | Train 0.9682 | Validation 0.9456
# Epoch 113 | Loss 0.1111 | Train 0.9683 | Validation 0.9460
# Epoch 114 | Loss 0.1102 | Train 0.9685 | Validation 0.9462
# Epoch 115 | Loss 0.1170 | Train 0.9687 | Validation 0.9466
# Epoch 116 | Loss 0.1121 | Train 0.9690 | Validation 0.9467
# Epoch 117 | Loss 0.1170 | Train 0.9691 | Validation 0.9470
# Epoch 118 | Loss 0.1075 | Train 0.9690 | Validation 0.9476
# Epoch 119 | Loss 0.1107 | Train 0.9690 | Validation 0.9477
# Epoch 120 | Loss 0.1100 | Train 0.9689 | Validation 0.9479
# Epoch 121 | Loss 0.1069 | Train 0.9688 | Validation 0.9476
# Epoch 122 | Loss 0.1087 | Train 0.9688 | Validation 0.9472
# Epoch 123 | Loss 0.1100 | Train 0.9687 | Validation 0.9471
# Epoch 124 | Loss 0.1137 | Train 0.9686 | Validation 0.9470
# Epoch 125 | Loss 0.1092 | Train 0.9686 | Validation 0.9473
# Epoch 126 | Loss 0.1148 | Train 0.9687 | Validation 0.9476
# Epoch 127 | Loss 0.1059 | Train 0.9687 | Validation 0.9480
# Epoch 128 | Loss 0.1135 | Train 0.9687 | Validation 0.9481
# Epoch 129 | Loss 0.1057 | Train 0.9687 | Validation 0.9479
# Epoch 130 | Loss 0.1103 | Train 0.9687 | Validation 0.9482
# Epoch 131 | Loss 0.1090 | Train 0.9687 | Validation 0.9481
# Epoch 132 | Loss 0.1058 | Train 0.9686 | Validation 0.9478
# Epoch 133 | Loss 0.1073 | Train 0.9686 | Validation 0.9477
# Epoch 134 | Loss 0.1132 | Train 0.9686 | Validation 0.9476
# Epoch 135 | Loss 0.1093 | Train 0.9686 | Validation 0.9476
# Epoch 136 | Loss 0.1121 | Train 0.9686 | Validation 0.9469
# Epoch 137 | Loss 0.1138 | Train 0.9685 | Validation 0.9461
# Epoch 138 | Loss 0.1131 | Train 0.9683 | Validation 0.9458
# Epoch 139 | Loss 0.1120 | Train 0.9683 | Validation 0.9462
# Epoch 140 | Loss 0.1149 | Train 0.9683 | Validation 0.9458
# Epoch 141 | Loss 0.1148 | Train 0.9683 | Validation 0.9454
# Epoch 142 | Loss 0.1079 | Train 0.9683 | Validation 0.9455
# Epoch 143 | Loss 0.1059 | Train 0.9682 | Validation 0.9454
# Epoch 144 | Loss 0.1085 | Train 0.9683 | Validation 0.9453
# Epoch 145 | Loss 0.1129 | Train 0.9683 | Validation 0.9454
# Epoch 146 | Loss 0.1118 | Train 0.9683 | Validation 0.9452
# Epoch 147 | Loss 0.1080 | Train 0.9683 | Validation 0.9453
# Epoch 148 | Loss 0.1060 | Train 0.9684 | Validation 0.9457
# Epoch 149 | Loss 0.1072 | Train 0.9685 | Validation 0.9459
# Epoch 150 | Loss 0.1064 | Train 0.9686 | Validation 0.9459
#
# ============================================================
# Training Time          : 146.36 seconds
# Best Epoch             : 130
# Best Validation Acc.   : 0.9482
# Model Saved At         : /content/drive/MyDrive/CIC_IoT_2023/Saved_Model/HostFlow_graphSAGE.pth
# Scaler Saved At        : /content/drive/MyDrive/CIC_IoT_2023/Saved_Model/HostFlow_scaler.pkl
# ============================================================
# Training Complete.

# %%
import time
import torch

print("=" * 60)

# Training Time
print(f"Training Time: {training_time:.2f} seconds ({150} epochs)\n")

# GPU Memory
if torch.cuda.is_available():

    allocated = torch.cuda.memory_allocated() / (1024 ** 2)
    reserved = torch.cuda.memory_reserved() / (1024 ** 2)
    max_reserved = torch.cuda.max_memory_reserved() / (1024 ** 2)

    print(f"Allocated GPU Memory: {allocated:.2f} MB")
    print(f"Reserved GPU Memory: {reserved:.2f} MB")
    print(f"Max GPU Memory: {max_reserved:.2f} MB\n")

# Model Parameters
total_params = sum(
    p.numel() for p in model.parameters()
)

trainable_params = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print(f"Total Parameters: {total_params}")
print(f"Trainable Parameters: {trainable_params}\n")

# Graph Memory
node_memory = (
    graph.x.element_size()
    * graph.x.nelement()
) / (1024 ** 2)

edge_memory = (
    graph.edge_index.element_size()
    * graph.edge_index.nelement()
) / (1024 ** 2)

graph_memory = node_memory + edge_memory

print(f"Node Feature Memory: {node_memory:.2f} MB")
print(f"Edge Memory: {edge_memory:.2f} MB")
print(f"Total Graph Memory: {graph_memory:.2f} MB")

print("=" * 60)
# Out:
# ============================================================
# Training Time: 146.36 seconds (150 epochs)
#
# Allocated GPU Memory: 131.54 MB
# Reserved GPU Memory: 10464.00 MB
# Max GPU Memory: 10464.00 MB
#
# Total Parameters: 214146
# Trainable Parameters: 214146
#
# Node Feature Memory: 46.30 MB
# Edge Memory: 60.85 MB
# Total Graph Memory: 107.15 MB
# ============================================================
