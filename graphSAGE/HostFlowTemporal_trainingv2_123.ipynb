# %% [markdown]
# <a href="https://colab.research.google.com/github/SAINIDHI2005/IDS_GNN_Repo/blob/main/graphSAGE/HostFlowTemporal_trainingv2_123.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install torch-geometric -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.4/64.4 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 40.8 MB/s eta 0:00:00

# %%
import os

import pandas as pd
import numpy as np

import torch

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from torch_geometric.data import Data

# %%
import random
import numpy as np
import torch

SEED = 123

random.seed(SEED)
np.random.seed(SEED)

torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
DATASET_DIR = "/content/drive/MyDrive/CIC_IoT_2023/Host_flow_temporal"

files = {
    "BENIGN.csv":0,
    "DDoS.csv":1,
    "DoS.csv":1,
    "Mirai.csv":1,
    "Recon.csv":1,
    "Spoofing.csv":1
}

dfs = []

for file,label in files.items():

    path = os.path.join(DATASET_DIR,file)

    df = pd.read_csv(path)

    attack_name = file.replace(".csv","")

    df["attack_type"] = attack_name

    df["label"] = label

    dfs.append(df)

data = pd.concat(
    dfs,
    ignore_index=True
)

print(data.shape)

print(data["attack_type"].value_counts())
# Out:
# (400000, 88)
# attack_type
# BENIGN      200000
# DDoS         40000
# DoS          40000
# Mirai        40000
# Recon        40000
# Spoofing     40000
# Name: count, dtype: int64

# %%
data = data.sort_values(
    "bidirectional_first_seen_ms"
).reset_index(drop=True)

data["flow_id"] = np.arange(len(data))

print(data.shape)
# Out:
# (400000, 89)

# %%
attack_type_backup = data["attack_type"].copy()

# %%
DROP_COLS = [

    "id",
    "expiration_id",

    "src_ip",
    "dst_ip",

    "src_mac",
    "dst_mac",

    "src_oui",
    "dst_oui",

    "requested_server_name",

    "client_fingerprint",
    "server_fingerprint",

    "user_agent",
    "content_type",

    "application_name",
    "application_category_name",

    "flow_id",
    "label",
    "attack_type",

    "bidirectional_first_seen_ms",
    "bidirectional_last_seen_ms",

    "src2dst_first_seen_ms",
    "src2dst_last_seen_ms",

    "dst2src_first_seen_ms",
    "dst2src_last_seen_ms",

    "application_confidence",
    "application_is_guessed",

    "vlan_id",
    "tunnel_id",

    "bidirectional_urg_packets",
    "src2dst_urg_packets",
    "dst2src_urg_packets",

    "dst2src_cwr_packets",
    "dst2src_ece_packets",

    "src_port",

    "bidirectional_duration_ms",
    "bidirectional_packets",

    "src2dst_packets",
    "dst2src_packets",

    "dst2src_min_ps",
    "dst2src_mean_ps",

    "bidirectional_min_piat_ms",
    "bidirectional_stddev_piat_ms",

    "dst2src_min_piat_ms",
    "dst2src_mean_piat_ms",
    "dst2src_max_piat_ms",

    "bidirectional_ece_packets",
    "bidirectional_psh_packets",
    "bidirectional_fin_packets",

    "src2dst_syn_packets",
    "src2dst_cwr_packets",
    "src2dst_ack_packets",
    "src2dst_rst_packets",
    "src2dst_fin_packets",

    "src2dst_mean_piat_ms",
    "src2dst_stddev_ps",

    "dst2src_ack_packets",
    "dst2src_psh_packets",
    "dst2src_rst_packets",
    "dst2src_fin_packets",

]

feature_cols = [

    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:",len(feature_cols))
# Out:
# Features: 30

# %%
feature_cols = [
    c
    for c in data.columns
    if c not in DROP_COLS
]

print("Features:", len(feature_cols))

print("\nRetained Features:\n")
for i, f in enumerate(feature_cols, start=1):
    print(f"{i:2d}. {f}")
# Out:
# Features: 30
#
# Retained Features:
#
#  1. dst_port
#  2. protocol
#  3. ip_version
#  4. bidirectional_bytes
#  5. src2dst_duration_ms
#  6. src2dst_bytes
#  7. dst2src_duration_ms
#  8. dst2src_bytes
#  9. bidirectional_min_ps
# 10. bidirectional_mean_ps
# 11. bidirectional_stddev_ps
# 12. bidirectional_max_ps
# 13. src2dst_min_ps
# 14. src2dst_mean_ps
# 15. src2dst_max_ps
# 16. dst2src_stddev_ps
# 17. dst2src_max_ps
# 18. bidirectional_mean_piat_ms
# 19. bidirectional_max_piat_ms
# 20. src2dst_min_piat_ms
# 21. src2dst_stddev_piat_ms
# 22. src2dst_max_piat_ms
# 23. dst2src_stddev_piat_ms
# 24. bidirectional_syn_packets
# 25. bidirectional_cwr_packets
# 26. bidirectional_ack_packets
# 27. bidirectional_rst_packets
# 28. src2dst_ece_packets
# 29. src2dst_psh_packets
# 30. dst2src_syn_packets

# %%
top30 = {
    "bidirectional_mean_ps",
    "dst2src_syn_packets",
    "src2dst_min_ps",
    "ip_version",
    "src2dst_max_piat_ms",
    "dst2src_stddev_piat_ms",
    "bidirectional_max_piat_ms",
    "bidirectional_rst_packets",
    "src2dst_max_ps",
    "src2dst_duration_ms",
    "src2dst_bytes",
    "src2dst_ece_packets",
    "bidirectional_max_ps",
    "dst2src_bytes",
    "bidirectional_bytes",
    "dst2src_max_ps",
    "bidirectional_min_ps",
    "bidirectional_syn_packets",
    "dst2src_stddev_ps",
    "bidirectional_ack_packets",
    "protocol",
    "dst_port",
    "bidirectional_mean_piat_ms",
    "dst2src_duration_ms",
    "src2dst_mean_ps",
    "src2dst_min_piat_ms",
    "bidirectional_stddev_ps",
    "src2dst_stddev_piat_ms",
    "bidirectional_cwr_packets",
    "src2dst_psh_packets"
}

retained = set(feature_cols)

print("Missing from retained:")
print(sorted(top30 - retained))

print("\nExtra retained features:")
print(sorted(retained - top30))
# Out:
# Missing from retained:
# []
#
# Extra retained features:
# []

# %%
for col in feature_cols:

    data[col] = pd.to_numeric(
        data[col],
        errors="coerce"
    )

data[feature_cols] = (
    data[feature_cols]
    .fillna(0)
)

# %%
scaler = StandardScaler()

X = scaler.fit_transform(
    data[feature_cols]
)

print(X.shape)
# Out:
# (400000, 30)

# %%
all_hosts = pd.concat(
    [
        data["src_ip"],
        data["dst_ip"]
    ]
).unique()

host_to_id = {

    host : idx + len(data)

    for idx,host
    in enumerate(all_hosts)
}

num_flow_nodes = len(data)

num_host_nodes = len(all_hosts)

print("Flow Nodes:",num_flow_nodes)
print("Host Nodes:",num_host_nodes)
# Out:
# Flow Nodes: 400000
# Host Nodes: 4572

# %%
edges = []

for flow_id,row in data.iterrows():

    src_host = host_to_id[
        row["src_ip"]
    ]

    dst_host = host_to_id[
        row["dst_ip"]
    ]

    edges.append(
        [flow_id,src_host]
    )

    edges.append(
        [src_host,flow_id]
    )

    edges.append(
        [flow_id,dst_host]
    )

    edges.append(
        [dst_host,flow_id]
    )

print("Host-flow edges built")
# Out:
# Host-flow edges built

# %%
src_groups = data.groupby(
    "src_ip"
)["flow_id"].apply(list)

print(
    "Groups:",
    len(src_groups)
)
# Out:
# Groups: 1303

# %%
# ==================================
# TEMPORAL FLOW-FLOW EDGES
# ==================================

src_groups = data.groupby("src_ip")["flow_id"].apply(list)

temporal_edges = 0

for flow_list in src_groups:

    n = len(flow_list)

    if n < 2:
        continue

    for i in range(n):

        f1 = flow_list[i]

        for k in [1, 2, 3]:

            if i + k < n:

                f2 = flow_list[i + k]

                edges.append([f1, f2])
                edges.append([f2, f1])

                temporal_edges += 2

print("Temporal edges added:", temporal_edges)
print("Total edges:", len(edges))
# Out:
# Temporal edges added: 2388190
# Total edges: 3988190

# %%
edge_index = torch.tensor(
    edges,
    dtype=torch.long
).t().contiguous()

print(edge_index.shape)
# Out:
# torch.Size([2, 3988190])

# %%
flow_features = torch.tensor(
    X,
    dtype=torch.float
)

# %%
host_features = torch.zeros(

    (
        num_host_nodes,
        flow_features.shape[1]
    ),

    dtype=torch.float
)

host_counts = np.zeros(
    num_host_nodes
)

for flow_id,row in data.iterrows():

    src_idx = (
        host_to_id[
            row["src_ip"]
        ]
        -
        num_flow_nodes
    )

    dst_idx = (
        host_to_id[
            row["dst_ip"]
        ]
        -
        num_flow_nodes
    )

    host_features[src_idx] += flow_features[flow_id]
    host_features[dst_idx] += flow_features[flow_id]

    host_counts[src_idx] += 1
    host_counts[dst_idx] += 1

for i in range(num_host_nodes):

    if host_counts[i] > 0:

        host_features[i] /= (
            host_counts[i]
        )

# %%
x = torch.cat(
    [
        flow_features,
        host_features
    ],
    dim=0
)

print(x.shape)
# Out:
# torch.Size([404572, 30])

# %%
flow_labels = torch.tensor(
    data["label"].values,
    dtype=torch.long
)

host_labels = torch.full(
    (
        num_host_nodes,
    ),
    -1,
    dtype=torch.long
)

y = torch.cat(
    [
        flow_labels,
        host_labels
    ]
)

print(y.shape)
# Out:
# torch.Size([404572])

# %%
flow_hosts = (
    data["src_ip"].astype(str)
    + "_"
    + data["dst_ip"].astype(str)
)

unique_pairs = flow_hosts.unique()

train_pairs, val_pairs = train_test_split(
    unique_pairs,
    test_size=0.2,
    random_state=42
)

train_idx = data[
    flow_hosts.isin(train_pairs)
].index.values

val_idx = data[
    flow_hosts.isin(val_pairs)
].index.values

print("Train flows:", len(train_idx))
print("Validation flows:", len(val_idx))

print("Train pairs:", len(train_pairs))
print("Validation pairs:", len(val_pairs))
# Out:
# Train flows: 313475
# Validation flows: 86525
# Train pairs: 9756
# Validation pairs: 2439

# %%
total_nodes = (
    num_flow_nodes
    +
    num_host_nodes
)

train_mask = torch.zeros(total_nodes,dtype=torch.bool)

val_mask = torch.zeros(total_nodes,dtype=torch.bool)

train_mask[train_idx] = True
val_mask[val_idx] = True

print("Train mask:", train_mask.sum().item())
print("Validation mask :",val_mask.sum().item())
# Out:
# Train mask: 313475
# Validation mask : 86525

# %%
graph = Data(
    x=x,
    edge_index=edge_index,
    y=y,
    train_mask=train_mask,
    val_mask=val_mask
)
print(graph)

print(
    "Nodes:",
    graph.num_nodes
)

print(
    "Edges:",
    graph.num_edges
)
# Out:
# Data(x=[404572, 30], edge_index=[2, 3988190], y=[404572], train_mask=[404572], val_mask=[404572])
# Nodes: 404572
# Edges: 3988190

# %%
import torch
import torch.nn.functional as F

from torch_geometric.nn import SAGEConv

class GraphSAGE(torch.nn.Module):

    def __init__(
        self,
        in_channels,
        hidden_channels,
        num_classes
    ):

        super().__init__()

        self.conv1 = SAGEConv(
            in_channels,
            hidden_channels
        )

        self.conv2 = SAGEConv(
            hidden_channels,
            hidden_channels
        )

        self.conv3 = SAGEConv(
            hidden_channels,
            hidden_channels // 2
        )

        self.bn1 = torch.nn.BatchNorm1d(
            hidden_channels
        )

        self.bn2 = torch.nn.BatchNorm1d(
            hidden_channels
        )

        self.bn3 = torch.nn.BatchNorm1d(
            hidden_channels // 2
        )

        self.classifier = torch.nn.Linear(
            hidden_channels // 2,
            num_classes
        )

    def forward(
        self,
        x,
        edge_index
    ):

        x = self.conv1(
            x,
            edge_index
        )

        x = self.bn1(x)

        x = F.relu(x)

        x = F.dropout(
            x,
            p=0.4,
            training=self.training
        )

        x = self.conv2(
            x,
            edge_index
        )

        x = self.bn2(x)

        x = F.relu(x)

        x = F.dropout(
            x,
            p=0.4,
            training=self.training
        )

        x = self.conv3(
            x,
            edge_index
        )

        x = self.bn3(x)

        x = F.relu(x)

        x = self.classifier(x)

        return x

# %%
device = torch.device(
    "cuda"
    if torch.cuda.is_available()
    else "cpu"
)

print(device)
# Out:
# cuda

# %%
model = GraphSAGE(
    in_channels=graph.num_node_features,
    hidden_channels=256,
    num_classes=2
)

model = model.to(device)

graph = graph.to(device)

print(model)
# Out:
# GraphSAGE(
#   (conv1): SAGEConv(30, 256, aggr=mean)
#   (conv2): SAGEConv(256, 256, aggr=mean)
#   (conv3): SAGEConv(256, 128, aggr=mean)
#   (bn1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (classifier): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
optimizer = torch.optim.Adam(
    model.parameters(),
    lr=0.002,
    weight_decay=5e-4
)

scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=150
)

# %%
weights = torch.tensor(
    [1.0, 1.5],
    dtype=torch.float
).to(device)

criterion = torch.nn.CrossEntropyLoss(
    weight=weights
)

# %%
def train():

    model.train()

    optimizer.zero_grad()

    out = model(
        graph.x,
        graph.edge_index
    )

    loss = criterion(
        out[graph.train_mask],
        graph.y[graph.train_mask]
    )

    loss.backward()

    optimizer.step()

    return loss.item()

# %%
@torch.no_grad()

def evaluate(mask):

    model.eval()

    out = model(
        graph.x,
        graph.edge_index
    )

    pred = out.argmax(
        dim=1
    )

    correct = (
        pred[mask]
        ==
        graph.y[mask]
    ).sum()

    acc = (
        correct.item()
        /
        mask.sum().item()
    )

    return acc

# %%
import os
import time
import joblib
import torch

best_val_acc = 0.0
best_epoch = 0

SAVE_DIR = r"/content/drive/MyDrive/CIC_IoT_2023/Saved_Model"
os.makedirs(SAVE_DIR, exist_ok=True)

start_time = time.time()

for epoch in range(1, 181):

    loss = train()

    train_acc = evaluate(graph.train_mask)
    val_acc = evaluate(graph.val_mask)

    # Save best model based on validation accuracy
    if val_acc > best_val_acc:

        best_val_acc = val_acc
        best_epoch = epoch

        torch.save(
            model.state_dict(),
            os.path.join(
                SAVE_DIR,
                "HostFlowTemporal_graphSAGE_imp123.pth"
            )
        )

        joblib.dump(
            scaler,
            os.path.join(
                SAVE_DIR,
                "HostFlowTemporal_scaler_imp123.pkl"
            )
        )

    scheduler.step()

    print(
        f"Epoch {epoch:03d}"
        f" | Loss {loss:.4f}"
        f" | Train {train_acc:.4f}"
        f" | Validation {val_acc:.4f}"
    )

end_time = time.time()

training_time = end_time - start_time

print("\n" + "=" * 60)
print(f"Training Time          : {training_time:.2f} seconds")
print(f"Best Epoch             : {best_epoch}")
print(f"Best Validation Acc.   : {best_val_acc:.4f}")
print(f"Model Saved At         : {os.path.join(SAVE_DIR,'HostFlow_graphSAGE_imp123.pth')}")
print(f"Scaler Saved At        : {os.path.join(SAVE_DIR,'HostFlow_scaler_imp123.pkl')}")
print("=" * 60)
print("Training Complete.")
# Out:
# Epoch 001 | Loss 0.6560 | Train 0.5358 | Validation 0.3704
# Epoch 002 | Loss 0.5606 | Train 0.7408 | Validation 0.8042
# Epoch 003 | Loss 0.4828 | Train 0.8042 | Validation 0.8115
# Epoch 004 | Loss 0.4432 | Train 0.8200 | Validation 0.8193
# Epoch 005 | Loss 0.4056 | Train 0.8265 | Validation 0.8224
# Epoch 006 | Loss 0.3808 | Train 0.8407 | Validation 0.8266
# Epoch 007 | Loss 0.3675 | Train 0.8459 | Validation 0.8292
# Epoch 008 | Loss 0.3489 | Train 0.8504 | Validation 0.8323
# Epoch 009 | Loss 0.3295 | Train 0.8550 | Validation 0.8319
# Epoch 010 | Loss 0.3166 | Train 0.8639 | Validation 0.8319
# Epoch 011 | Loss 0.3027 | Train 0.8642 | Validation 0.8298
# Epoch 012 | Loss 0.2890 | Train 0.8663 | Validation 0.8303
# Epoch 013 | Loss 0.2813 | Train 0.8718 | Validation 0.8395
# Epoch 014 | Loss 0.2705 | Train 0.8743 | Validation 0.8446
# Epoch 015 | Loss 0.2616 | Train 0.8782 | Validation 0.8485
# Epoch 016 | Loss 0.2524 | Train 0.8846 | Validation 0.8490
# Epoch 017 | Loss 0.2478 | Train 0.8838 | Validation 0.8464
# Epoch 018 | Loss 0.2381 | Train 0.8896 | Validation 0.8502
# Epoch 019 | Loss 0.2329 | Train 0.9033 | Validation 0.8569
# Epoch 020 | Loss 0.2260 | Train 0.9059 | Validation 0.8582
# Epoch 021 | Loss 0.2243 | Train 0.9076 | Validation 0.8563
# Epoch 022 | Loss 0.2118 | Train 0.8985 | Validation 0.8532
# Epoch 023 | Loss 0.2069 | Train 0.9009 | Validation 0.8551
# Epoch 024 | Loss 0.1986 | Train 0.9046 | Validation 0.8607
# Epoch 025 | Loss 0.2029 | Train 0.8982 | Validation 0.8549
# Epoch 026 | Loss 0.1934 | Train 0.8962 | Validation 0.8515
# Epoch 027 | Loss 0.1906 | Train 0.9136 | Validation 0.8568
# Epoch 028 | Loss 0.1849 | Train 0.9198 | Validation 0.8635
# Epoch 029 | Loss 0.1769 | Train 0.9089 | Validation 0.8618
# Epoch 030 | Loss 0.1753 | Train 0.9091 | Validation 0.8613
# Epoch 031 | Loss 0.1741 | Train 0.9245 | Validation 0.8660
# Epoch 032 | Loss 0.1624 | Train 0.9293 | Validation 0.8909
# Epoch 033 | Loss 0.1637 | Train 0.9356 | Validation 0.8939
# Epoch 034 | Loss 0.1527 | Train 0.9384 | Validation 0.8959
# Epoch 035 | Loss 0.1508 | Train 0.9435 | Validation 0.9069
# Epoch 036 | Loss 0.1513 | Train 0.9489 | Validation 0.9168
# Epoch 037 | Loss 0.1453 | Train 0.9502 | Validation 0.9181
# Epoch 038 | Loss 0.1412 | Train 0.9521 | Validation 0.9209
# Epoch 039 | Loss 0.1472 | Train 0.9530 | Validation 0.9176
# Epoch 040 | Loss 0.1388 | Train 0.9537 | Validation 0.9182
# Epoch 041 | Loss 0.1373 | Train 0.9556 | Validation 0.9235
# Epoch 042 | Loss 0.1362 | Train 0.9558 | Validation 0.9252
# Epoch 043 | Loss 0.1294 | Train 0.9557 | Validation 0.9276
# Epoch 044 | Loss 0.1280 | Train 0.9574 | Validation 0.9290
# Epoch 045 | Loss 0.1291 | Train 0.9589 | Validation 0.9310
# Epoch 046 | Loss 0.1202 | Train 0.9613 | Validation 0.9355
# Epoch 047 | Loss 0.1214 | Train 0.9633 | Validation 0.9391
# Epoch 048 | Loss 0.1153 | Train 0.9640 | Validation 0.9419
# Epoch 049 | Loss 0.1213 | Train 0.9654 | Validation 0.9441
# Epoch 050 | Loss 0.1146 | Train 0.9655 | Validation 0.9437
# Epoch 051 | Loss 0.1125 | Train 0.9655 | Validation 0.9419
# Epoch 052 | Loss 0.1160 | Train 0.9652 | Validation 0.9398
# Epoch 053 | Loss 0.1125 | Train 0.9665 | Validation 0.9419
# Epoch 054 | Loss 0.1092 | Train 0.9654 | Validation 0.9436
# Epoch 055 | Loss 0.1118 | Train 0.9667 | Validation 0.9406
# Epoch 056 | Loss 0.1032 | Train 0.9665 | Validation 0.9393
# Epoch 057 | Loss 0.1088 | Train 0.9685 | Validation 0.9437
# Epoch 058 | Loss 0.1086 | Train 0.9685 | Validation 0.9476
# Epoch 059 | Loss 0.1093 | Train 0.9701 | Validation 0.9506
# Epoch 060 | Loss 0.1033 | Train 0.9693 | Validation 0.9492
# Epoch 061 | Loss 0.1048 | Train 0.9713 | Validation 0.9500
# Epoch 062 | Loss 0.1009 | Train 0.9720 | Validation 0.9514
# Epoch 063 | Loss 0.1009 | Train 0.9717 | Validation 0.9514
# Epoch 064 | Loss 0.1008 | Train 0.9736 | Validation 0.9542
# Epoch 065 | Loss 0.1005 | Train 0.9729 | Validation 0.9549
# Epoch 066 | Loss 0.0954 | Train 0.9738 | Validation 0.9586
# Epoch 067 | Loss 0.0986 | Train 0.9732 | Validation 0.9601
# Epoch 068 | Loss 0.1034 | Train 0.9720 | Validation 0.9552
# Epoch 069 | Loss 0.0936 | Train 0.9704 | Validation 0.9504
# Epoch 070 | Loss 0.0948 | Train 0.9735 | Validation 0.9521
# Epoch 071 | Loss 0.0992 | Train 0.9745 | Validation 0.9539
# Epoch 072 | Loss 0.1002 | Train 0.9744 | Validation 0.9565
# Epoch 073 | Loss 0.0954 | Train 0.9752 | Validation 0.9585
# Epoch 074 | Loss 0.0906 | Train 0.9760 | Validation 0.9581
# Epoch 075 | Loss 0.0899 | Train 0.9760 | Validation 0.9577
# Epoch 076 | Loss 0.0908 | Train 0.9758 | Validation 0.9588
# Epoch 077 | Loss 0.0862 | Train 0.9761 | Validation 0.9601
# Epoch 078 | Loss 0.0885 | Train 0.9761 | Validation 0.9606
# Epoch 079 | Loss 0.0939 | Train 0.9752 | Validation 0.9595
# Epoch 080 | Loss 0.0876 | Train 0.9752 | Validation 0.9605
# Epoch 081 | Loss 0.0872 | Train 0.9761 | Validation 0.9632
# Epoch 082 | Loss 0.0852 | Train 0.9759 | Validation 0.9646
# Epoch 083 | Loss 0.0926 | Train 0.9762 | Validation 0.9655
# Epoch 084 | Loss 0.0897 | Train 0.9766 | Validation 0.9657
# Epoch 085 | Loss 0.0869 | Train 0.9782 | Validation 0.9647
# Epoch 086 | Loss 0.0871 | Train 0.9786 | Validation 0.9638
# Epoch 087 | Loss 0.0851 | Train 0.9785 | Validation 0.9624
# Epoch 088 | Loss 0.0820 | Train 0.9786 | Validation 0.9618
# Epoch 089 | Loss 0.0857 | Train 0.9792 | Validation 0.9622
# Epoch 090 | Loss 0.0869 | Train 0.9795 | Validation 0.9638
# Epoch 091 | Loss 0.0835 | Train 0.9795 | Validation 0.9647
# Epoch 092 | Loss 0.0860 | Train 0.9796 | Validation 0.9647
# Epoch 093 | Loss 0.0826 | Train 0.9793 | Validation 0.9638
# Epoch 094 | Loss 0.0778 | Train 0.9790 | Validation 0.9628
# Epoch 095 | Loss 0.0824 | Train 0.9790 | Validation 0.9626
# Epoch 096 | Loss 0.0802 | Train 0.9790 | Validation 0.9635
# Epoch 097 | Loss 0.0816 | Train 0.9791 | Validation 0.9637
# Epoch 098 | Loss 0.0800 | Train 0.9791 | Validation 0.9639
# Epoch 099 | Loss 0.0818 | Train 0.9790 | Validation 0.9639
# Epoch 100 | Loss 0.0808 | Train 0.9792 | Validation 0.9654
# Epoch 101 | Loss 0.0799 | Train 0.9800 | Validation 0.9667
# Epoch 102 | Loss 0.0792 | Train 0.9805 | Validation 0.9670
# Epoch 103 | Loss 0.0814 | Train 0.9807 | Validation 0.9669
# Epoch 104 | Loss 0.0788 | Train 0.9809 | Validation 0.9672
# Epoch 105 | Loss 0.0799 | Train 0.9810 | Validation 0.9672
# Epoch 106 | Loss 0.0770 | Train 0.9811 | Validation 0.9671
# Epoch 107 | Loss 0.0800 | Train 0.9812 | Validation 0.9663
# Epoch 108 | Loss 0.0810 | Train 0.9810 | Validation 0.9649
# Epoch 109 | Loss 0.0787 | Train 0.9808 | Validation 0.9641
# Epoch 110 | Loss 0.0791 | Train 0.9810 | Validation 0.9644
# Epoch 111 | Loss 0.0747 | Train 0.9809 | Validation 0.9649
# Epoch 112 | Loss 0.0776 | Train 0.9811 | Validation 0.9652
# Epoch 113 | Loss 0.0746 | Train 0.9810 | Validation 0.9655
# Epoch 114 | Loss 0.0793 | Train 0.9812 | Validation 0.9657
# Epoch 115 | Loss 0.0759 | Train 0.9812 | Validation 0.9654
# Epoch 116 | Loss 0.0804 | Train 0.9811 | Validation 0.9646
# Epoch 117 | Loss 0.0817 | Train 0.9811 | Validation 0.9639
# Epoch 118 | Loss 0.0788 | Train 0.9813 | Validation 0.9639
# Epoch 119 | Loss 0.0764 | Train 0.9813 | Validation 0.9642
# Epoch 120 | Loss 0.0788 | Train 0.9810 | Validation 0.9641
# Epoch 121 | Loss 0.0768 | Train 0.9811 | Validation 0.9643
# Epoch 122 | Loss 0.0743 | Train 0.9812 | Validation 0.9641
# Epoch 123 | Loss 0.0780 | Train 0.9812 | Validation 0.9643
# Epoch 124 | Loss 0.0729 | Train 0.9813 | Validation 0.9645
# Epoch 125 | Loss 0.0754 | Train 0.9812 | Validation 0.9645
# Epoch 126 | Loss 0.0746 | Train 0.9813 | Validation 0.9647
# Epoch 127 | Loss 0.0769 | Train 0.9812 | Validation 0.9646
# Epoch 128 | Loss 0.0776 | Train 0.9813 | Validation 0.9649
# Epoch 129 | Loss 0.0768 | Train 0.9814 | Validation 0.9648
# Epoch 130 | Loss 0.0738 | Train 0.9814 | Validation 0.9648
# Epoch 131 | Loss 0.0735 | Train 0.9814 | Validation 0.9649
# Epoch 132 | Loss 0.0760 | Train 0.9814 | Validation 0.9648
# Epoch 133 | Loss 0.0783 | Train 0.9813 | Validation 0.9645
# Epoch 134 | Loss 0.0740 | Train 0.9814 | Validation 0.9646
# Epoch 135 | Loss 0.0748 | Train 0.9814 | Validation 0.9645
# Epoch 136 | Loss 0.0768 | Train 0.9813 | Validation 0.9642
# Epoch 137 | Loss 0.0782 | Train 0.9814 | Validation 0.9642
# Epoch 138 | Loss 0.0737 | Train 0.9814 | Validation 0.9643
# Epoch 139 | Loss 0.0748 | Train 0.9814 | Validation 0.9644
# Epoch 140 | Loss 0.0760 | Train 0.9814 | Validation 0.9643
# Epoch 141 | Loss 0.0748 | Train 0.9815 | Validation 0.9644
# Epoch 142 | Loss 0.0783 | Train 0.9815 | Validation 0.9642
# Epoch 143 | Loss 0.0743 | Train 0.9814 | Validation 0.9641
# Epoch 144 | Loss 0.0781 | Train 0.9815 | Validation 0.9640
# Epoch 145 | Loss 0.0739 | Train 0.9815 | Validation 0.9641
# Epoch 146 | Loss 0.0747 | Train 0.9815 | Validation 0.9641
# Epoch 147 | Loss 0.0745 | Train 0.9816 | Validation 0.9641
# Epoch 148 | Loss 0.0762 | Train 0.9815 | Validation 0.9640
# Epoch 149 | Loss 0.0739 | Train 0.9814 | Validation 0.9638
# Epoch 150 | Loss 0.0703 | Train 0.9815 | Validation 0.9639
# Epoch 151 | Loss 0.0721 | Train 0.9814 | Validation 0.9638
# Epoch 152 | Loss 0.0749 | Train 0.9814 | Validation 0.9637
# Epoch 153 | Loss 0.0734 | Train 0.9814 | Validation 0.9637
# Epoch 154 | Loss 0.0736 | Train 0.9814 | Validation 0.9637
# Epoch 155 | Loss 0.0735 | Train 0.9814 | Validation 0.9638
# Epoch 156 | Loss 0.0745 | Train 0.9813 | Validation 0.9634
# Epoch 157 | Loss 0.0722 | Train 0.9814 | Validation 0.9635
# Epoch 158 | Loss 0.0737 | Train 0.9814 | Validation 0.9636
# Epoch 159 | Loss 0.0743 | Train 0.9814 | Validation 0.9636
# Epoch 160 | Loss 0.0751 | Train 0.9813 | Validation 0.9635
# Epoch 161 | Loss 0.0771 | Train 0.9814 | Validation 0.9636
# Epoch 162 | Loss 0.0757 | Train 0.9814 | Validation 0.9636
# Epoch 163 | Loss 0.0734 | Train 0.9813 | Validation 0.9633
# Epoch 164 | Loss 0.0754 | Train 0.9813 | Validation 0.9635
# Epoch 165 | Loss 0.0735 | Train 0.9814 | Validation 0.9637
# Epoch 166 | Loss 0.0778 | Train 0.9812 | Validation 0.9634
# Epoch 167 | Loss 0.0750 | Train 0.9813 | Validation 0.9634
# Epoch 168 | Loss 0.0734 | Train 0.9812 | Validation 0.9634
# Epoch 169 | Loss 0.0739 | Train 0.9812 | Validation 0.9634
# Epoch 170 | Loss 0.0738 | Train 0.9812 | Validation 0.9635
# Epoch 171 | Loss 0.0743 | Train 0.9812 | Validation 0.9640
# Epoch 172 | Loss 0.0739 | Train 0.9813 | Validation 0.9645
# Epoch 173 | Loss 0.0735 | Train 0.9814 | Validation 0.9649
# Epoch 174 | Loss 0.0756 | Train 0.9815 | Validation 0.9652
# Epoch 175 | Loss 0.0727 | Train 0.9816 | Validation 0.9652
# Epoch 176 | Loss 0.0757 | Train 0.9818 | Validation 0.9651
# Epoch 177 | Loss 0.0781 | Train 0.9821 | Validation 0.9658
# Epoch 178 | Loss 0.0752 | Train 0.9820 | Validation 0.9657
# Epoch 179 | Loss 0.0787 | Train 0.9819 | Validation 0.9650
# Epoch 180 | Loss 0.0751 | Train 0.9818 | Validation 0.9645
#
# ============================================================
# Training Time          : 174.45 seconds
# Best Epoch             : 104
# Best Validation Acc.   : 0.9672
# Model Saved At         : /content/drive/MyDrive/CIC_IoT_2023/Saved_Model/HostFlow_graphSAGE_imp5.2.pth
# Scaler Saved At        : /content/drive/MyDrive/CIC_IoT_2023/Saved_Model/HostFlow_scaler_imp5.2.pkl
# ============================================================
# Training Complete.

# %%
import time
import torch

print("=" * 60)

# Training Time
print(f"Training Time: {training_time:.2f} seconds ({150} epochs)\n")

# GPU Memory
if torch.cuda.is_available():

    allocated = torch.cuda.memory_allocated() / (1024 ** 2)
    reserved = torch.cuda.memory_reserved() / (1024 ** 2)
    max_reserved = torch.cuda.max_memory_reserved() / (1024 ** 2)

    print(f"Allocated GPU Memory: {allocated:.2f} MB")
    print(f"Reserved GPU Memory: {reserved:.2f} MB")
    print(f"Max GPU Memory: {max_reserved:.2f} MB\n")

# Model Parameters
total_params = sum(
    p.numel() for p in model.parameters()
)

trainable_params = sum(
    p.numel()
    for p in model.parameters()
    if p.requires_grad
)

print(f"Total Parameters: {total_params}")
print(f"Trainable Parameters: {trainable_params}\n")

# Graph Memory
node_memory = (
    graph.x.element_size()
    * graph.x.nelement()
) / (1024 ** 2)

edge_memory = (
    graph.edge_index.element_size()
    * graph.edge_index.nelement()
) / (1024 ** 2)

graph_memory = node_memory + edge_memory

print(f"Node Feature Memory: {node_memory:.2f} MB")
print(f"Edge Memory: {edge_memory:.2f} MB")
print(f"Total Graph Memory: {graph_memory:.2f} MB")

print("=" * 60)
# Out:
# ============================================================
# Training Time: 174.45 seconds (150 epochs)
#
# Allocated GPU Memory: 131.54 MB
# Reserved GPU Memory: 10464.00 MB
# Max GPU Memory: 10464.00 MB
#
# Total Parameters: 214146
# Trainable Parameters: 214146
#
# Node Feature Memory: 46.30 MB
# Edge Memory: 60.85 MB
# Total Graph Memory: 107.15 MB
# ============================================================
